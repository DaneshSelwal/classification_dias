# %% [markdown]
# # 1.0 — Setup & Imports
# Mount Google Drive and import all required standard, third-party, and ML libraries.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Standard library
import io
import json
import os
import random
import time
from pathlib import Path

# Third-party – .mat file I/O
from scipy.io import loadmat

# Third-party – data / viz
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib.colors import ListedColormap
from openpyxl import Workbook, load_workbook
from openpyxl.drawing.image import Image as XLImage
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    cohen_kappa_score,
    confusion_matrix,
    f1_score,
    log_loss,
)
from sklearn.model_selection import train_test_split

# TensorFlow / Keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, regularizers

sns.set_style("whitegrid")
print("TensorFlow:", tf.__version__)
# Out:
# TensorFlow: 2.20.0

# %% [markdown]
# # 2.0 — Configuration
# All hyper-parameters, paths, and architecture configs are defined here. Change values in this single cell to reconfigure the whole notebook.

# %%
# ── Reproducibility ──────────────────────────────────────────────────
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# ── Paths ─────────────────────────────────────────────────────────────
MODEL_DIR   = Path("/content/drive/My Drive/Classification/baseline/models")
RESULTS_DIR = Path("/content/drive/My Drive/Classification/baseline/results")
MODEL_DIR.mkdir(parents=True, exist_ok=True)
RESULTS_DIR.mkdir(parents=True, exist_ok=True)
PLOT_DIR    = RESULTS_DIR / "training_plots"
PLOT_DIR.mkdir(parents=True, exist_ok=True)
VIS_DIR     = RESULTS_DIR / "scene_visualizations"
VIS_DIR.mkdir(parents=True, exist_ok=True)

DATA_DIR   = Path("/content/drive/My Drive/Classification/data")
DATA_FILE  = DATA_DIR / "DIAS.mat"      # hyperspectral cube (H, W, Bands)
LABEL_FILE = DATA_DIR / "DIAS_ref.mat"  # reference / ground-truth label map (H, W)

# ── Dataset geometry ─────────────────────────────────────────────────
# H, W, B are no longer hard-coded — they are inferred automatically from
# the .mat cube shape once it is loaded in Section 3.2, so this notebook
# works unchanged for any scene size / band count.
H, W, B     = None, None, None
PERCENTILE_CLIP = (2.0, 98.0)  # robust per-band stretch range for load_scene_from_mat
PATCH_SIZE  = 9
INNER_PATCH = 3                   # tokenisation patch size for GFNet / ViT

# ── Train / val / test splits ─────────────────────────────────────────
TRAIN_PERCENT          = 0.75
VAL_SPLIT_FROM_TRAIN   = 0.20

# ── Training ──────────────────────────────────────────────────────────
BATCH_SIZE    = 128
EPOCHS        = 100
LEARNING_RATE = 3e-4
DROPOUT_RATE  = 0.25
CAPACITY_PRESET = "legacy_arch"

TRAIN_CFG = {
    "label_smoothing": 0.05,
    "weight_decay":    1e-4,
    "clipnorm":        1.0,
    "cosine_alpha":    0.05,
}

# ── AlexNet legacy recipe (reproduces original single-head results) ────
ALEXNET_LEGACY_SPLIT_SEED   = 10
ALEXNET_LEGACY_TRAIN_PERCENT = 0.75
ALEXNET_LR_START = 0.01
ALEXNET_LR_MAX   = 0.02
ALEXNET_LR_MIN   = 0.005

# ── Architecture configs ──────────────────────────────────────────────
ALEXNET_CFG = {
    "conv_filters": [96, 256, 384, 384, 256],
    "dense_units":  [4096, 1024, 256, 32],
}

GFNET_CFG = {"hidden_dim": 512, "num_blocks": 5, "mlp_ratio": 4}
VIT_CFG   = {
    "projection_dim":    256,
    "num_heads":         4,
    "transformer_layers": 12,
    "mlp_multiplier":    2,
    "head_units":        [512, 256, 128, 64],
}

# Fallback configs used when Colab runs out of memory
GFNET_FALLBACK_CFG = {"hidden_dim": 384, "num_blocks": 4, "mlp_ratio": 4}
VIT_FALLBACK_CFG   = {
    "projection_dim":    192,
    "num_heads":         4,
    "transformer_layers": 8,
    "mlp_multiplier":    2,
    "head_units":        [384, 192, 96, 64],
}

# ── Visualisation palette ─────────────────────────────────────────────
# Same bold, saturated palette used for the original 6-band/7-class scene.
# Auto-extended with additional bold shades (same style, not muted tab20)
# if a future dataset has more than 10 classes.
import colorsys

CLASS_COLOR_BASE = [
    "#0000FF", "#00FF00", "#FF0000", "#00FFFF", "#FF00FF",
    "#FFFF00", "#A52A2A", "#FFA500", "#7FFF00", "#8A2BE2",
]

def _generate_extra_shades(n_extra, hue_offset=0.05, sat=0.85, val=0.95):
    """Bold, highly-saturated extra hues in the same style as CLASS_COLOR_BASE."""
    shades = []
    for i in range(n_extra):
        hue = (hue_offset + i / max(n_extra, 1)) % 1.0
        r, g, b = colorsys.hsv_to_rgb(hue, sat, val)
        shades.append("#%02x%02x%02x" % (int(r * 255), int(g * 255), int(b * 255)))
    return shades

def get_class_colors(n):
    """Return n visually distinct hex colours; extends past the base 10 with
    additional bold shades generated in the same saturated style."""
    if n <= len(CLASS_COLOR_BASE):
        return CLASS_COLOR_BASE[:n]
    return CLASS_COLOR_BASE + _generate_extra_shades(n - len(CLASS_COLOR_BASE))

BACKGROUND_COLOR  = "#000000"
VIS_EXCEL_PATH    = VIS_DIR / "initial_classification_maps.xlsx"

print("Data file:    ", DATA_FILE)
print("Label file:   ", LABEL_FILE)
print("Model dir:    ", MODEL_DIR)
print("Results dir:  ", RESULTS_DIR)
print("Plot dir:     ", PLOT_DIR)
print("Arch preset:  ", CAPACITY_PRESET)
# Out:
# Data file:     /content/drive/My Drive/Classification/data/data.csv
# Label file:    /content/drive/My Drive/Classification/data/ref.csv
# Model dir:     /content/drive/My Drive/Classification/baseline/models
# Results dir:   /content/drive/My Drive/Classification/baseline/results
# Plot dir:      /content/drive/My Drive/Classification/baseline/results/training_plots
# Arch preset:   legacy_arch

# %% [markdown]
# # 3.0 — Data Loading & Preprocessing
# Load the hyperspectral/multispectral scene and reference labels from .mat files, apply per-band min-max normalisation, extract labelled patches, and create stratified train / val / test splits.

# %% [markdown]
# ## 3.1 — Loading and patch extraction helpers

# %%
def load_scene_from_mat(data_path, label_path, data_key=None, label_key=None):
    """Load a hyperspectral/multispectral scene + reference labels from .mat files.

    Works for any band count / scene size (previously hard-coded to 6-band CSV
    scenes). If data_key / label_key are not given, the first non-metadata
    variable in each .mat file is used automatically — this matches files
    such as DIAS.mat / DIAS_ref.mat where the array is stored under a single
    named variable. Each spectral band is robustly stretched to [0, 1] using
    a percentile clip (see PERCENTILE_CLIP) rather than literal min/max.
    """
    data_mat  = loadmat(data_path)
    label_mat = loadmat(label_path)

    def _first_array(mat_dict, key):
        if key is not None:
            return mat_dict[key]
        candidates = [v for k, v in mat_dict.items() if not k.startswith("__")]
        if not candidates:
            raise ValueError(f"No data arrays found in {mat_dict.keys()}")
        return candidates[0]

    x = _first_array(data_mat, data_key).astype(np.float32)
    y = _first_array(label_mat, label_key).astype(np.int32)

    if x.ndim != 3:
        raise ValueError(f"Expected a (H, W, Bands) cube, got shape {x.shape}")
    if y.shape != x.shape[:2]:
        raise ValueError(f"Label shape {y.shape} does not match image shape {x.shape[:2]}")

    height, width, bands = x.shape

    # Robust per-band stretch: clip to the [lower_pct, upper_pct] percentile
    # range before min-max scaling, instead of literal min/max. A handful of
    # saturated/no-data pixels (e.g. sensor clipping at the int8 range limits
    # -128/127) would otherwise dominate the stretch and crush the dynamic
    # range of the rest of the scene.
    x_norm = np.empty_like(x, dtype=np.float32)
    for b in range(bands):
        band = x[:, :, b]
        lo   = np.percentile(band, PERCENTILE_CLIP[0])
        hi   = np.percentile(band, PERCENTILE_CLIP[1])
        denom = max(hi - lo, 1e-8)
        band_clipped = np.clip(band, lo, hi)
        x_norm[:, :, b] = (band_clipped - lo) / denom

    return x_norm, y, height, width, bands


def extract_labeled_patches(x, y, patch_size=9):
    """Extract (patch_size × patch_size) spatial patches around every labelled pixel."""
    pad   = patch_size // 2
    x_pad = np.pad(x, ((pad, pad), (pad, pad), (0, 0)), mode="edge")

    coords  = np.argwhere(y > 0)
    patches = np.empty((coords.shape[0], patch_size, patch_size, x.shape[-1]), dtype=np.float32)
    labels  = np.empty((coords.shape[0],), dtype=np.int32)

    for i, (r, c) in enumerate(coords):
        patches[i] = x_pad[r:r + patch_size, c:c + patch_size, :]
        labels[i]  = int(y[r, c]) - 1  # convert class IDs to 0..C-1

    return patches, labels, coords

# %% [markdown]
# ## 3.2 — Load data and create splits

# %%
x_img, y_img, H, W, B = load_scene_from_mat(DATA_FILE, LABEL_FILE)
X, y, coords = extract_labeled_patches(x_img, y_img, PATCH_SIZE)

num_classes = int(np.unique(y).size)
input_shape = (PATCH_SIZE, PATCH_SIZE, B)

print("Scene geometry:  H=%d  W=%d  Bands=%d" % (H, W, B))
print("x_img:", x_img.shape, "  y_img:", y_img.shape)
print("Labelled samples:", X.shape[0])
print("Patch tensor:    ", X.shape)
print("Num classes:     ", num_classes)
# Out:
# x_img: (330, 307, 6)   y_img: (330, 307)
# Labelled samples: 17239
# Patch tensor:     (17239, 9, 9, 6)
# Num classes:      7

# %%
# Primary stratified split used by GFNet and ViT
x_train_full, x_test, y_train_full, y_test = train_test_split(
    X, y,
    train_size=TRAIN_PERCENT,
    random_state=SEED,
    stratify=y,
)
x_train, x_val, y_train, y_val = train_test_split(
    x_train_full, y_train_full,
    test_size=VAL_SPLIT_FROM_TRAIN,
    random_state=SEED,
    stratify=y_train_full,
)

y_train_cat = keras.utils.to_categorical(y_train, num_classes)
y_val_cat   = keras.utils.to_categorical(y_val,   num_classes)
y_test_cat  = keras.utils.to_categorical(y_test,  num_classes)

print("Train:", x_train.shape, y_train.shape)
print("Val:  ", x_val.shape,   y_val.shape)
print("Test: ", x_test.shape,  y_test.shape)
# Out:
# Train: (10343, 9, 9, 6) (10343,)
# Val:   (2586, 9, 9, 6) (2586,)
# Test:  (4310, 9, 9, 6) (4310,)

# %%
# AlexNet legacy split — matches the original single-head notebook for
# uncertainty recovery (different seed and no val split)
x_train_alex, x_test_alex, y_train_alex, y_test_alex = train_test_split(
    X, y,
    train_size=ALEXNET_LEGACY_TRAIN_PERCENT,
    random_state=ALEXNET_LEGACY_SPLIT_SEED,
    stratify=y,
)
y_train_alex_cat = keras.utils.to_categorical(y_train_alex, num_classes)
y_test_alex_cat  = keras.utils.to_categorical(y_test_alex,  num_classes)

print("AlexNet Train:", x_train_alex.shape, y_train_alex.shape)
print("AlexNet Test: ", x_test_alex.shape,  y_test_alex.shape)
# Out:
# AlexNet Train: (12929, 9, 9, 6) (12929,)
# AlexNet Test:  (4310, 9, 9, 6) (4310,)

# %% [markdown]
# # 4.0 — Model Definitions
# Defines three single-head architectures: AlexNet-based CNN, Global Filter Network (GFNet), and Vision Transformer (ViT with U-Net style skip connections). Custom Keras layers are registered for serialisation.

# %% [markdown]
# ## 4.1 — Shared custom Keras layers (PatchExtractor, PatchPositionEncoder, PatchEncoderWithCLS)

# %%
@tf.keras.utils.register_keras_serializable()
class PatchExtractor(layers.Layer):
    """Extract non-overlapping spatial patches from an image tensor."""

    def __init__(self, patch_size=3, **kwargs):
        super().__init__(**kwargs)
        self.patch_size = patch_size

    def call(self, images):
        patches     = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        batch       = tf.shape(images)[0]
        num_patches = tf.shape(patches)[1] * tf.shape(patches)[2]
        patch_dim   = tf.shape(patches)[-1]
        return tf.reshape(patches, [batch, num_patches, patch_dim])

    def get_config(self):
        cfg = super().get_config()
        cfg.update({"patch_size": self.patch_size})
        return cfg


@tf.keras.utils.register_keras_serializable()
class PatchPositionEncoder(layers.Layer):
    """Project patches to embedding dim and add learned positional embeddings."""

    def __init__(self, num_patches, projection_dim, **kwargs):
        super().__init__(**kwargs)
        self.num_patches      = num_patches
        self.projection_dim   = projection_dim
        self.projection       = layers.Dense(projection_dim)
        self.position_embedding = layers.Embedding(input_dim=num_patches, output_dim=projection_dim)

    def call(self, patches):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        return self.projection(patches) + self.position_embedding(positions)

    def get_config(self):
        cfg = super().get_config()
        cfg.update({"num_patches": self.num_patches, "projection_dim": self.projection_dim})
        return cfg


@tf.keras.utils.register_keras_serializable()
class PatchEncoderWithCLS(layers.Layer):
    """Project patches and prepend a learnable [CLS] token with positional embeddings."""

    def __init__(self, num_patches, projection_dim, **kwargs):
        super().__init__(**kwargs)
        self.num_patches      = num_patches
        self.projection_dim   = projection_dim
        self.projection       = layers.Dense(projection_dim)
        self.position_embedding = layers.Embedding(input_dim=num_patches + 1, output_dim=projection_dim)

    def build(self, input_shape):
        self.cls_token = self.add_weight(
            name="cls_token",
            shape=(1, 1, self.projection_dim),
            initializer="zeros",
            trainable=True,
        )
        super().build(input_shape)

    def call(self, patches):
        batch      = tf.shape(patches)[0]
        patch_proj = self.projection(patches)
        cls_tokens = tf.repeat(self.cls_token, repeats=batch, axis=0)
        x          = tf.concat([cls_tokens, patch_proj], axis=1)
        positions  = tf.range(start=0, limit=self.num_patches + 1, delta=1)
        return x + self.position_embedding(positions)

    def get_config(self):
        cfg = super().get_config()
        cfg.update({"num_patches": self.num_patches, "projection_dim": self.projection_dim})
        return cfg

# %% [markdown]
# ## 4.2 — AlexNet-based CNN

# %%
def build_alexnet(input_shape, num_classes, dropout_rate=0.25, cfg=None):
    """Build an AlexNet-inspired CNN with five conv layers and four dense layers."""
    cfg = cfg or ALEXNET_CFG

    inputs = keras.Input(shape=input_shape)
    x      = inputs
    for i, filters in enumerate(cfg["conv_filters"], start=1):
        x = layers.Conv2D(filters, (3, 3), activation="relu", padding="same", name=f"alex_conv_{i}")(x)

    x = layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding="same", name="alex_pool")(x)
    x = layers.Flatten(name="alex_flatten")(x)

    dense_units = cfg["dense_units"]
    x = layers.Dense(dense_units[0], activation="relu", name="alex_fc1")(x)
    x = layers.Dropout(dropout_rate, name="TRAIN_DROPOUT_1")(x)
    x = layers.Dense(dense_units[1], activation="relu", name="alex_fc2")(x)
    x = layers.Dropout(dropout_rate, name="TRAIN_DROPOUT_2")(x)
    x = layers.Dense(dense_units[2], activation="relu", name="alex_fc3")(x)
    x = layers.Dropout(dropout_rate, name="TRAIN_DROPOUT_3")(x)
    x = layers.Dense(dense_units[3], activation="relu", name="alex_fc4")(x)

    outputs = layers.Dense(num_classes, activation="softmax", name="alex_logits")(x)
    return keras.Model(inputs, outputs, name="AlexNet_SingleHead")

# %% [markdown]
# ## 4.3 — Global Filter Network (GFNet)

# %%
@tf.keras.utils.register_keras_serializable()
class GlobalFilterLayer(layers.Layer):
    """Apply learnable complex-valued filters in the 2-D frequency domain."""

    def __init__(self, token_side, **kwargs):
        super().__init__(**kwargs)
        self.token_side = token_side

    def build(self, input_shape):
        channels    = int(input_shape[-1])
        self.w_real = self.add_weight(
            name="w_real",
            shape=(self.token_side, self.token_side, channels),
            initializer="glorot_uniform",
            trainable=True,
        )
        self.w_imag = self.add_weight(
            name="w_imag",
            shape=(self.token_side, self.token_side, channels),
            initializer="zeros",
            trainable=True,
        )
        super().build(input_shape)

    def call(self, x):
        batch      = tf.shape(x)[0]
        channels   = tf.shape(x)[-1]
        x_2d       = tf.reshape(x, [batch, self.token_side, self.token_side, channels])
        x_fft      = tf.signal.fft2d(tf.cast(x_2d, tf.complex64))
        w_complex  = tf.complex(self.w_real, self.w_imag)
        x_filtered = x_fft * w_complex
        x_spatial  = tf.math.real(tf.signal.ifft2d(x_filtered))
        return tf.reshape(x_spatial, [batch, self.token_side * self.token_side, channels])

    def get_config(self):
        cfg = super().get_config()
        cfg.update({"token_side": self.token_side})
        return cfg


def gf_block(x, token_side, dim, mlp_ratio=4, dropout_rate=0.25, name_prefix="gf"):
    """Single GFNet residual block: global filter followed by a two-layer MLP."""
    # Legacy block style: one residual add after filter + MLP branch
    y = layers.LayerNormalization(name=f"{name_prefix}_ln1")(x)
    y = GlobalFilterLayer(token_side, name=f"{name_prefix}_gfilter")(y)
    y = layers.LayerNormalization(name=f"{name_prefix}_ln2")(y)
    y = layers.Dense(dim * mlp_ratio, activation=tf.keras.activations.gelu, name=f"{name_prefix}_mlp1")(y)
    y = layers.Dropout(dropout_rate, name=f"{name_prefix}_drop1")(y)
    y = layers.Dense(dim, activation=tf.keras.activations.gelu, name=f"{name_prefix}_mlp2")(y)
    y = layers.Dropout(dropout_rate, name=f"{name_prefix}_drop2")(y)
    return layers.Add(name=f"{name_prefix}_add")([x, y])


def build_gfnet(input_shape, num_classes, inner_patch=3, hidden_dim=512,
                num_blocks=5, mlp_ratio=4, dropout_rate=0.25):
    """Build a Global Filter Network (GFNet) single-head classifier."""
    num_patches = (input_shape[0] // inner_patch) * (input_shape[1] // inner_patch)
    token_side  = int(np.sqrt(num_patches))

    inputs = keras.Input(shape=input_shape)
    x      = PatchExtractor(inner_patch, name="gf_patch_extractor")(inputs)
    x      = PatchPositionEncoder(num_patches, hidden_dim, name="gf_patch_encoder")(x)
    x      = layers.Dropout(dropout_rate, name="TRAIN_DROPOUT_1")(x)

    for i in range(num_blocks):
        x = gf_block(x, token_side, hidden_dim, mlp_ratio, dropout_rate, name_prefix=f"gf_block_{i+1}")

    x = layers.Dropout(dropout_rate, name="TRAIN_DROPOUT_2")(x)
    x = layers.LayerNormalization(name="gf_final_ln")(x)
    x = layers.GlobalAveragePooling1D(name="gf_gap")(x)
    x = layers.Flatten(name="gf_flatten")(x)
    x = layers.Dropout(dropout_rate, name="TRAIN_DROPOUT_3")(x)

    outputs = layers.Dense(num_classes, activation="softmax", name="gf_logits")(x)
    return keras.Model(inputs, outputs, name="GFNet_SingleHead")

# %% [markdown]
# ## 4.4 — Vision Transformer with U-Net style skip connections

# %%
def transformer_block(x, num_heads, projection_dim, mlp_dim, dropout_rate, name_prefix):
    """Standard pre-LN transformer block with multi-head attention and a GELU MLP."""
    y = layers.LayerNormalization(epsilon=1e-6, name=f"{name_prefix}_ln1")(x)
    y = layers.MultiHeadAttention(
        num_heads=num_heads, key_dim=projection_dim,
        dropout=dropout_rate, name=f"{name_prefix}_mha",
    )(y, y)
    x = layers.Add(name=f"{name_prefix}_add1")([y, x])

    y = layers.LayerNormalization(epsilon=1e-6, name=f"{name_prefix}_ln2")(x)
    y = layers.Dense(mlp_dim, activation=tf.keras.activations.gelu, name=f"{name_prefix}_mlp1")(y)
    y = layers.Dropout(dropout_rate, name=f"{name_prefix}_drop1")(y)
    y = layers.Dense(projection_dim, activation=tf.keras.activations.gelu, name=f"{name_prefix}_mlp2")(y)
    y = layers.Dropout(dropout_rate, name=f"{name_prefix}_drop2")(y)
    return layers.Add(name=f"{name_prefix}_add2")([y, x])


def build_vit_unet_singlehead(
    input_shape, num_classes, inner_patch=3,
    projection_dim=256, num_heads=4, transformer_layers=12,
    mlp_multiplier=2, dropout_rate=0.25, head_units=(512, 256, 128, 64),
):
    """Build a ViT single-head classifier with U-Net style encoder–decoder skip connections."""
    num_patches = (input_shape[0] // inner_patch) * (input_shape[1] // inner_patch)

    inputs = keras.Input(shape=input_shape)
    x      = PatchExtractor(inner_patch, name="vit_patch_extractor")(inputs)
    x      = PatchEncoderWithCLS(num_patches, projection_dim, name="vit_patch_encoder")(x)

    block_list = []
    for i in range(transformer_layers):
        x = transformer_block(
            x, num_heads=num_heads, projection_dim=projection_dim,
            mlp_dim=projection_dim * mlp_multiplier,
            dropout_rate=0.1, name_prefix=f"vit_block_{i+1}",
        )
        if i <= transformer_layers // 2:
            block_list.append(x)
        else:
            x = layers.Add(name=f"vit_skip_add_{i+1}")([x, block_list[transformer_layers - i - 1]])

    x         = layers.Dropout(dropout_rate, name="TRAIN_DROPOUT_1")(x)
    x         = layers.LayerNormalization(epsilon=1e-6, name="vit_cls_norm")(x)
    cls_token = layers.Lambda(lambda t: t[:, 0, :], name="vit_cls_token")(x)

    y = layers.Dense(head_units[0], activation=tf.keras.activations.gelu, name="vit_head_1")(cls_token)
    y = layers.Dropout(dropout_rate, name="TRAIN_DROPOUT_3")(y)
    y = layers.Dense(head_units[1], activation=tf.keras.activations.gelu, name="vit_head_2")(y)
    y = layers.Dense(head_units[2], activation=tf.keras.activations.gelu, name="vit_head_3")(y)
    y = layers.Dropout(dropout_rate, name="TRAIN_DROPOUT_5")(y)
    y = layers.Dense(head_units[3], activation=tf.keras.activations.gelu, name="vit_head_4")(y)
    y = layers.Dropout(dropout_rate, name="TRAIN_DROPOUT_6")(y)

    outputs = layers.Dense(num_classes, activation="softmax", name="vit_logits")(y)
    return keras.Model(inputs, outputs, name="ViT_UNet_SingleHead")

# %% [markdown]
# # 5.0 — Training & Evaluation Helpers
# Optimiser factory, learning-rate schedule, calibration metrics (Brier score, ECE), and the main `train_save_evaluate` function.

# %% [markdown]
# ## 5.1 — Calibration metrics

# %%
def multiclass_brier_score(y_onehot, y_prob):
    """Compute the multiclass Brier score (mean squared error over probability vectors)."""
    return float(np.mean(np.sum((y_prob - y_onehot) ** 2, axis=1)))


def expected_calibration_error(y_true, y_prob, n_bins=15):
    """Compute Expected Calibration Error (ECE) with equal-width confidence bins."""
    confidences = np.max(y_prob, axis=1)
    predictions = np.argmax(y_prob, axis=1)
    correct     = (predictions == y_true).astype(np.float32)
    bin_edges   = np.linspace(0.0, 1.0, n_bins + 1)
    ece         = 0.0

    for i in range(n_bins):
        lo, hi = bin_edges[i], bin_edges[i + 1]
        in_bin = (confidences >= lo) & (confidences <= hi if i == n_bins - 1 else confidences < hi)
        prop   = np.mean(in_bin)
        if prop > 0:
            ece += np.abs(np.mean(correct[in_bin]) - np.mean(confidences[in_bin])) * prop

    return float(ece)

# %% [markdown]
# ## 5.2 — Optimiser factory

# %%
def make_optimizer(num_train_samples):
    """Build an AdamW optimiser with a cosine-decay learning-rate schedule."""
    steps_per_epoch = int(np.ceil(num_train_samples / BATCH_SIZE))
    decay_steps     = max(1, steps_per_epoch * EPOCHS)
    lr_schedule     = keras.optimizers.schedules.CosineDecay(
        initial_learning_rate=LEARNING_RATE,
        decay_steps=decay_steps,
        alpha=TRAIN_CFG["cosine_alpha"],
    )
    return keras.optimizers.AdamW(
        learning_rate=lr_schedule,
        weight_decay=TRAIN_CFG["weight_decay"],
        clipnorm=TRAIN_CFG["clipnorm"],
    )


def _alexnet_legacy_lr(epoch):
    """Cosine LR schedule for AlexNet, matching the original single-head script."""
    if EPOCHS <= 1:
        return ALEXNET_LR_START
    phase        = np.pi * epoch / (EPOCHS - 1)
    cosine_decay = 0.5 * (1.0 + np.cos(phase))
    return float((ALEXNET_LR_MAX - ALEXNET_LR_MIN) * cosine_decay + ALEXNET_LR_MIN)

# %% [markdown]
# ## 5.3 — Main training, saving, and evaluation function

# %%
def train_save_evaluate(model_name, model_builder, capacity_tag="max"):
    """Compile, train, save (best + final), and evaluate a single-head model.

    Returns a metrics dict, per-class classification report, confusion matrix,
    and the raw Keras history dict.
    """
    tf.keras.backend.clear_session()
    model     = model_builder()
    best_path  = MODEL_DIR / f"{model_name}_best.keras"
    final_path = MODEL_DIR / f"{model_name}_final.keras"

    # AlexNet uses a legacy Adagrad + cosine LR schedule to match the original
    # single-head script for downstream uncertainty analysis.
    if model_name == "AlexNet_CNN":
        model.compile(
            optimizer=keras.optimizers.Adagrad(learning_rate=ALEXNET_LR_START),
            loss="sparse_categorical_crossentropy",
            metrics=["accuracy"],
        )
        callbacks = [
            keras.callbacks.ModelCheckpoint(
                filepath=str(best_path), monitor="val_accuracy",
                mode="max", save_best_only=True, verbose=1,
            ),
            keras.callbacks.LearningRateScheduler(_alexnet_legacy_lr, verbose=0),
        ]
        x_tr, y_tr         = x_train_alex, y_train_alex
        x_va, y_va         = x_test_alex,  y_test_alex
        x_te, y_te, y_te_cat = x_test_alex, y_test_alex, y_test_alex_cat
        x_eval, y_eval, y_eval_cat = x_test_alex, y_test_alex, y_test_alex_cat
        fit_shuffle        = False
    else:
        # GFNet and ViT use AdamW + cosine decay with label smoothing
        model.compile(
            optimizer=make_optimizer(len(x_train)),
            loss=keras.losses.CategoricalCrossentropy(label_smoothing=TRAIN_CFG["label_smoothing"]),
            metrics=["accuracy"],
        )
        callbacks = [
            keras.callbacks.ModelCheckpoint(
                filepath=str(best_path), monitor="val_loss",
                mode="min", save_best_only=True, verbose=1,
            ),
        ]
        x_tr, y_tr         = x_train, y_train_cat
        x_va, y_va         = x_val,   y_val_cat
        x_te, y_te, y_te_cat = x_test, y_test, y_test_cat
        x_eval, y_eval, y_eval_cat = x_val, y_val, y_val_cat
        fit_shuffle        = True

    train_start = time.perf_counter()
    history_obj = model.fit(
        x_tr, y_tr,
        validation_data=(x_va, y_va),
        epochs=EPOCHS,
        batch_size=BATCH_SIZE,
        callbacks=callbacks,
        verbose=1,
        shuffle=fit_shuffle,
    )
    train_time_sec = float(time.perf_counter() - train_start)

    epochs_ran = int(len(history_obj.history.get("loss", [])))
    if epochs_ran != EPOCHS:
        print(f"WARNING: {model_name} ran {epochs_ran} epochs, expected {EPOCHS}.")
    else:
        print(f"{model_name} completed full training: {epochs_ran}/{EPOCHS} epochs.")

    model.save(final_path)

    y_eval_prob = model.predict(x_eval, batch_size=BATCH_SIZE, verbose=0)
    y_test_prob = model.predict(x_te,   batch_size=BATCH_SIZE, verbose=0)
    y_test_pred = np.argmax(y_test_prob, axis=1)

    report = classification_report(y_te, y_test_pred, output_dict=True, zero_division=0)
    cm     = confusion_matrix(y_te, y_test_pred)

    row = {
        "model":            model_name,
        "capacity_tag":     capacity_tag,
        "test_accuracy":    float(accuracy_score(y_te, y_test_pred)),
        "kappa":            float(cohen_kappa_score(y_te, y_test_pred)),
        "macro_f1":         float(f1_score(y_te, y_test_pred, average="macro")),
        "weighted_f1":      float(f1_score(y_te, y_test_pred, average="weighted")),
        "val_nll":          float(log_loss(y_eval, y_eval_prob, labels=np.arange(num_classes))),
        "test_nll":         float(log_loss(y_te,   y_test_prob, labels=np.arange(num_classes))),
        "val_brier":        multiclass_brier_score(y_eval_cat, y_eval_prob),
        "test_brier":       multiclass_brier_score(y_te_cat,   y_test_prob),
        "test_ece_15bin":   expected_calibration_error(y_te, y_test_prob, n_bins=15),
        "epochs_configured": int(EPOCHS),
        "epochs_ran":       epochs_ran,
        "train_time_sec":   train_time_sec,
        "best_model_path":  str(best_path),
        "final_model_path": str(final_path),
    }
    return row, report, cm, history_obj.history

# %% [markdown]
# # 6.0 — Model Training
# Build factory lambdas, then loop over all three architectures. OOM errors on GFNet and ViT automatically retry with reduced fallback configs.

# %%
def build_gfnet_with_cfg(cfg):
    """Instantiate GFNet from a config dict."""
    return build_gfnet(
        input_shape, num_classes,
        inner_patch=INNER_PATCH,
        hidden_dim=cfg["hidden_dim"],
        num_blocks=cfg["num_blocks"],
        mlp_ratio=cfg["mlp_ratio"],
        dropout_rate=DROPOUT_RATE,
    )


def build_vit_with_cfg(cfg):
    """Instantiate ViT-UNet from a config dict."""
    return build_vit_unet_singlehead(
        input_shape, num_classes,
        inner_patch=INNER_PATCH,
        projection_dim=cfg["projection_dim"],
        num_heads=cfg["num_heads"],
        transformer_layers=cfg["transformer_layers"],
        mlp_multiplier=cfg["mlp_multiplier"],
        dropout_rate=DROPOUT_RATE,
        head_units=tuple(cfg["head_units"]),
    )


model_builders = {
    "AlexNet_CNN": lambda: build_alexnet(input_shape, num_classes,
                                         dropout_rate=DROPOUT_RATE, cfg=ALEXNET_CFG),
    "GFNet":       lambda: build_gfnet_with_cfg(GFNET_CFG),
    "ViT_UNet":    lambda: build_vit_with_cfg(VIT_CFG),
}

# %%
results_rows   = []
model_artifacts = {}

for model_name, builder in model_builders.items():
    print(f"\n{'=' * 25} Training {model_name} ({CAPACITY_PRESET}) {'=' * 25}")

    try:
        row, report, cm, history = train_save_evaluate(model_name, builder,
                                                       capacity_tag=CAPACITY_PRESET)
    except tf.errors.ResourceExhaustedError:
        # Automatically retry with a smaller fallback config to handle Colab OOM
        if model_name == "GFNet":
            print("OOM on GFNet legacy config. Retrying with fallback config.")
            tf.keras.backend.clear_session()
            row, report, cm, history = train_save_evaluate(
                model_name, lambda: build_gfnet_with_cfg(GFNET_FALLBACK_CFG),
                capacity_tag="fallback",
            )
        elif model_name == "ViT_UNet":
            print("OOM on ViT_UNet legacy config. Retrying with fallback config.")
            tf.keras.backend.clear_session()
            row, report, cm, history = train_save_evaluate(
                model_name, lambda: build_vit_with_cfg(VIT_FALLBACK_CFG),
                capacity_tag="fallback",
            )
        else:
            raise

    results_rows.append(row)
    model_artifacts[model_name] = {"report": report, "confusion_matrix": cm, "history": history}

summary_df = (
    pd.DataFrame(results_rows)
    .sort_values("test_accuracy", ascending=False)
    .reset_index(drop=True)
)
summary_df
# Out:
# ========================= Training AlexNet_CNN (legacy_arch) =========================
# Epoch 1/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.4006 - loss: 1.7212
# Epoch 1: val_accuracy improved from None to 0.54687, saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
#
# Epoch 1: finished saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 29s 163ms/step - accuracy: 0.4623 - loss: 1.5299 - val_accuracy: 0.5469 - val_loss: 1.3238 - learning_rate: 0.0200
# Epoch 2/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.5462 - loss: 1.1903
# Epoch 2: val_accuracy improved from 0.54687 to 0.60812, saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
#
# Epoch 2: finished saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - accuracy: 0.5701 - loss: 1.1108 - val_accuracy: 0.6081 - val_loss: 1.0109 - learning_rate: 0.0200
# Epoch 3/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6050 - loss: 1.0199
# Epoch 3: val_accuracy improved from 0.60812 to 0.65058, saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
#
# Epoch 3: finished saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.6132 - loss: 0.9855 - val_accuracy: 0.6506 - val_loss: 0.8708 - learning_rate: 0.0200
# Epoch 4/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6288 - loss: 0.9204
# Epoch 4: val_accuracy improved from 0.65058 to 0.68608, saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
#
# Epoch 4: finished saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.6419 - loss: 0.8951 - val_accuracy: 0.6861 - val_loss: 0.7995 - learning_rate: 0.0200
# Epoch 5/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.6800 - loss: 0.8184
# Epoch 5: val_accuracy improved from 0.68608 to 0.70603, saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
#
# Epoch 5: finished saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.6919 - loss: 0.7929 - val_accuracy: 0.7060 - val_loss: 0.7220 - learning_rate: 0.0199
# Epoch 6/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7186 - loss: 0.7238
# Epoch 6: val_accuracy improved from 0.70603 to 0.78585, saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
#
# Epoch 6: finished saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 83ms/step - accuracy: 0.7325 - loss: 0.6908 - val_accuracy: 0.7858 - val_loss: 0.5848 - learning_rate: 0.0199
# Epoch 7/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7633 - loss: 0.6310
# Epoch 7: val_accuracy improved from 0.78585 to 0.82483, saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
#
# Epoch 7: finished saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 10s 76ms/step - accuracy: 0.7710 - loss: 0.6116 - val_accuracy: 0.8248 - val_loss: 0.4872 - learning_rate: 0.0199
# Epoch 8/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8057 - loss: 0.5191
# Epoch 8: val_accuracy improved from 0.82483 to 0.85313, saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
#
# Epoch 8: finished saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.8179 - loss: 0.4967 - val_accuracy: 0.8531 - val_loss: 0.4235 - learning_rate: 0.0198
# Epoch 9/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8299 - loss: 0.4630
# Epoch 9: val_accuracy improved from 0.85313 to 0.86845, saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
#
# Epoch 9: finished saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 9s 85ms/step - accuracy: 0.8400 - loss: 0.4402 - val_accuracy: 0.8684 - val_loss: 0.3770 - learning_rate: 0.0198
# Epoch 10/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8492 - loss: 0.4066
# Epoch 10: val_accuracy improved from 0.86845 to 0.87889, saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
#
# Epoch 10: finished saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 80ms/step - accuracy: 0.8577 - loss: 0.3875 - val_accuracy: 0.8789 - val_loss: 0.3345 - learning_rate: 0.0197
# Epoch 11/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8709 - loss: 0.3436
# Epoch 11: val_accuracy improved from 0.87889 to 0.90510, saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
#
# Epoch 11: finished saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 9s 84ms/step - accuracy: 0.8749 - loss: 0.3401 - val_accuracy: 0.9051 - val_loss: 0.2761 - learning_rate: 0.0196
# Epoch 12/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8865 - loss: 0.3079
# Epoch 12: val_accuracy improved from 0.90510 to 0.91833, saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
#
# Epoch 12: finished saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 82ms/step - accuracy: 0.8930 - loss: 0.2968 - val_accuracy: 0.9183 - val_loss: 0.2396 - learning_rate: 0.0195
# Epoch 13/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8916 - loss: 0.2859
# Epoch 13: val_accuracy improved from 0.91833 to 0.92274, saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
#
# Epoch 13: finished saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 81ms/step - accuracy: 0.8900 - loss: 0.2988 - val_accuracy: 0.9227 - val_loss: 0.2320 - learning_rate: 0.0195
# Epoch 14/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9087 - loss: 0.2446
# Epoch 14: val_accuracy improved from 0.92274 to 0.93735, saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
#
# Epoch 14: finished saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 80ms/step - accuracy: 0.9139 - loss: 0.2344 - val_accuracy: 0.9374 - val_loss: 0.1779 - learning_rate: 0.0194
# Epoch 15/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9197 - loss: 0.2129
# Epoch 15: val_accuracy did not improve from 0.93735
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - accuracy: 0.9217 - loss: 0.2132 - val_accuracy: 0.7457 - val_loss: 0.9513 - learning_rate: 0.0193
# Epoch 16/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9071 - loss: 0.2606
# Epoch 16: val_accuracy did not improve from 0.93735
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - accuracy: 0.9283 - loss: 0.1946 - val_accuracy: 0.8944 - val_loss: 0.2924 - learning_rate: 0.0192
# Epoch 17/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9332 - loss: 0.1806
# Epoch 17: val_accuracy improved from 0.93735 to 0.94756, saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
#
# Epoch 17: finished saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 80ms/step - accuracy: 0.9376 - loss: 0.1717 - val_accuracy: 0.9476 - val_loss: 0.1423 - learning_rate: 0.0191
# Epoch 18/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9411 - loss: 0.1559
# Epoch 18: val_accuracy improved from 0.94756 to 0.95916, saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
#
# Epoch 18: finished saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 80ms/step - accuracy: 0.9448 - loss: 0.1533 - val_accuracy: 0.9592 - val_loss: 0.1066 - learning_rate: 0.0189
# Epoch 19/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9511 - loss: 0.1365
# Epoch 19: val_accuracy improved from 0.95916 to 0.96056, saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
#
# Epoch 19: finished saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.9546 - loss: 0.1269 - val_accuracy: 0.9606 - val_loss: 0.1039 - learning_rate: 0.0188
# Epoch 20/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9546 - loss: 0.1324
# Epoch 20: val_accuracy improved from 0.96056 to 0.96682, saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
#
# Epoch 20: finished saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 9s 85ms/step - accuracy: 0.9539 - loss: 0.1385 - val_accuracy: 0.9668 - val_loss: 0.0894 - learning_rate: 0.0187
# Epoch 21/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9670 - loss: 0.0939
# Epoch 21: val_accuracy did not improve from 0.96682
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 65ms/step - accuracy: 0.9682 - loss: 0.0898 - val_accuracy: 0.9522 - val_loss: 0.1257 - learning_rate: 0.0185
# Epoch 22/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9703 - loss: 0.0846
# Epoch 22: val_accuracy did not improve from 0.96682
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - accuracy: 0.9727 - loss: 0.0770 - val_accuracy: 0.9661 - val_loss: 0.0899 - learning_rate: 0.0184
# Epoch 23/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9724 - loss: 0.0778
# Epoch 23: val_accuracy improved from 0.96682 to 0.97285, saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
#
# Epoch 23: finished saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 9s 86ms/step - accuracy: 0.9763 - loss: 0.0685 - val_accuracy: 0.9729 - val_loss: 0.0758 - learning_rate: 0.0182
# Epoch 24/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9545 - loss: 0.1357
# Epoch 24: val_accuracy improved from 0.97285 to 0.97309, saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
#
# Epoch 24: finished saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 79ms/step - accuracy: 0.9701 - loss: 0.0904 - val_accuracy: 0.9731 - val_loss: 0.0761 - learning_rate: 0.0181
# Epoch 25/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9806 - loss: 0.0569
# Epoch 25: val_accuracy improved from 0.97309 to 0.97401, saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
#
# Epoch 25: finished saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 79ms/step - accuracy: 0.9811 - loss: 0.0545 - val_accuracy: 0.9740 - val_loss: 0.0704 - learning_rate: 0.0179
# Epoch 26/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9715 - loss: 1.3636
# Epoch 26: val_accuracy did not improve from 0.97401
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 64ms/step - accuracy: 0.8759 - loss: 10.5928 - val_accuracy: 0.4241 - val_loss: 1.4973 - learning_rate: 0.0178
# Epoch 27/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5487 - loss: 1.2224
# Epoch 27: val_accuracy did not improve from 0.97401
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 64ms/step - accuracy: 0.5894 - loss: 1.0800 - val_accuracy: 0.6798 - val_loss: 0.8180 - learning_rate: 0.0176
# Epoch 28/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6632 - loss: 0.8336
# Epoch 28: val_accuracy did not improve from 0.97401
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 64ms/step - accuracy: 0.6901 - loss: 0.7746 - val_accuracy: 0.7369 - val_loss: 0.7141 - learning_rate: 0.0174
# Epoch 29/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7736 - loss: 0.6136
# Epoch 29: val_accuracy did not improve from 0.97401
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.7949 - loss: 0.5594 - val_accuracy: 0.8241 - val_loss: 0.4919 - learning_rate: 0.0172
# Epoch 30/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8344 - loss: 0.4590
# Epoch 30: val_accuracy did not improve from 0.97401
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 65ms/step - accuracy: 0.8453 - loss: 0.4314 - val_accuracy: 0.8752 - val_loss: 0.3771 - learning_rate: 0.0170
# Epoch 31/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8581 - loss: 0.3942
# Epoch 31: val_accuracy did not improve from 0.97401
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 10s 61ms/step - accuracy: 0.8688 - loss: 0.3668 - val_accuracy: 0.7480 - val_loss: 0.7160 - learning_rate: 0.0169
# Epoch 32/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8729 - loss: 0.3546
# Epoch 32: val_accuracy did not improve from 0.97401
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.8855 - loss: 0.3197 - val_accuracy: 0.8448 - val_loss: 0.4314 - learning_rate: 0.0167
# Epoch 33/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8844 - loss: 0.3179
# Epoch 33: val_accuracy did not improve from 0.97401
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.8983 - loss: 0.2834 - val_accuracy: 0.8631 - val_loss: 0.3892 - learning_rate: 0.0165
# Epoch 34/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9036 - loss: 0.2603
# Epoch 34: val_accuracy did not improve from 0.97401
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.9096 - loss: 0.2485 - val_accuracy: 0.9278 - val_loss: 0.1984 - learning_rate: 0.0162
# Epoch 35/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9150 - loss: 0.2345
# Epoch 35: val_accuracy did not improve from 0.97401
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.9196 - loss: 0.2276 - val_accuracy: 0.9142 - val_loss: 0.2398 - learning_rate: 0.0160
# Epoch 36/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9175 - loss: 0.2205
# Epoch 36: val_accuracy did not improve from 0.97401
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.9257 - loss: 0.2059 - val_accuracy: 0.9230 - val_loss: 0.2116 - learning_rate: 0.0158
# Epoch 37/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9315 - loss: 0.1907
# Epoch 37: val_accuracy did not improve from 0.97401
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.9360 - loss: 0.1823 - val_accuracy: 0.8965 - val_loss: 0.2961 - learning_rate: 0.0156
# Epoch 38/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9271 - loss: 0.1957
# Epoch 38: val_accuracy did not improve from 0.97401
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.9404 - loss: 0.1643 - val_accuracy: 0.9448 - val_loss: 0.1469 - learning_rate: 0.0154
# Epoch 39/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9411 - loss: 0.1701
# Epoch 39: val_accuracy did not improve from 0.97401
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.9488 - loss: 0.1488 - val_accuracy: 0.9522 - val_loss: 0.1294 - learning_rate: 0.0152
# Epoch 40/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9524 - loss: 0.1436
# Epoch 40: val_accuracy did not improve from 0.97401
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.9568 - loss: 0.1281 - val_accuracy: 0.9622 - val_loss: 0.1098 - learning_rate: 0.0150
# Epoch 41/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9563 - loss: 0.1250
# Epoch 41: val_accuracy did not improve from 0.97401
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.9599 - loss: 0.1140 - val_accuracy: 0.9617 - val_loss: 0.1056 - learning_rate: 0.0147
# Epoch 42/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9514 - loss: 0.1473
# Epoch 42: val_accuracy did not improve from 0.97401
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.9505 - loss: 0.1604 - val_accuracy: 0.9555 - val_loss: 0.1222 - learning_rate: 0.0145
# Epoch 43/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9688 - loss: 0.0965
# Epoch 43: val_accuracy did not improve from 0.97401
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.9698 - loss: 0.0893 - val_accuracy: 0.9638 - val_loss: 0.1036 - learning_rate: 0.0143
# Epoch 44/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9481 - loss: 0.1529
# Epoch 44: val_accuracy did not improve from 0.97401
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.9630 - loss: 0.1129 - val_accuracy: 0.9675 - val_loss: 0.0934 - learning_rate: 0.0140
# Epoch 45/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9742 - loss: 0.0756
# Epoch 45: val_accuracy improved from 0.97401 to 0.97912, saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
#
# Epoch 45: finished saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 75ms/step - accuracy: 0.9752 - loss: 0.0722 - val_accuracy: 0.9791 - val_loss: 0.0677 - learning_rate: 0.0138
# Epoch 46/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9710 - loss: 0.0879
# Epoch 46: val_accuracy did not improve from 0.97912
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.9718 - loss: 0.0826 - val_accuracy: 0.9719 - val_loss: 0.0775 - learning_rate: 0.0136
# Epoch 47/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9765 - loss: 0.0662
# Epoch 47: val_accuracy did not improve from 0.97912
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 65ms/step - accuracy: 0.9773 - loss: 0.0647 - val_accuracy: 0.9761 - val_loss: 0.0682 - learning_rate: 0.0133
# Epoch 48/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9791 - loss: 0.0602
# Epoch 48: val_accuracy improved from 0.97912 to 0.98005, saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
#
# Epoch 48: finished saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 81ms/step - accuracy: 0.9798 - loss: 0.0585 - val_accuracy: 0.9800 - val_loss: 0.0667 - learning_rate: 0.0131
# Epoch 49/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9813 - loss: 0.0557
# Epoch 49: val_accuracy improved from 0.98005 to 0.98260, saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
#
# Epoch 49: finished saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.9822 - loss: 0.0516 - val_accuracy: 0.9826 - val_loss: 0.0575 - learning_rate: 0.0129
# Epoch 50/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9841 - loss: 0.0488
# Epoch 50: val_accuracy did not improve from 0.98260
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.9855 - loss: 0.0453 - val_accuracy: 0.9807 - val_loss: 0.0539 - learning_rate: 0.0126
# Epoch 51/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9853 - loss: 0.0446
# Epoch 51: val_accuracy did not improve from 0.98260
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 65ms/step - accuracy: 0.9851 - loss: 0.0426 - val_accuracy: 0.9794 - val_loss: 0.0543 - learning_rate: 0.0124
# Epoch 52/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9853 - loss: 0.0425
# Epoch 52: val_accuracy improved from 0.98260 to 0.98329, saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
#
# Epoch 52: finished saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 9s 84ms/step - accuracy: 0.9867 - loss: 0.0376 - val_accuracy: 0.9833 - val_loss: 0.0439 - learning_rate: 0.0121
# Epoch 53/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9866 - loss: 0.0397
# Epoch 53: val_accuracy improved from 0.98329 to 0.98445, saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
#
# Epoch 53: finished saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.9875 - loss: 0.0372 - val_accuracy: 0.9845 - val_loss: 0.0420 - learning_rate: 0.0119
# Epoch 54/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9894 - loss: 0.0332
# Epoch 54: val_accuracy did not improve from 0.98445
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.9904 - loss: 0.0310 - val_accuracy: 0.9821 - val_loss: 0.0506 - learning_rate: 0.0117
# Epoch 55/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9894 - loss: 0.0313
# Epoch 55: val_accuracy did not improve from 0.98445
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.9896 - loss: 0.0306 - val_accuracy: 0.9803 - val_loss: 0.0597 - learning_rate: 0.0114
# Epoch 56/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9879 - loss: 0.0394
# Epoch 56: val_accuracy did not improve from 0.98445
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.9725 - loss: 0.1003 - val_accuracy: 0.9671 - val_loss: 0.1015 - learning_rate: 0.0112
# Epoch 57/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9863 - loss: 0.0499
# Epoch 57: val_accuracy improved from 0.98445 to 0.98654, saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
#
# Epoch 57: finished saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.9891 - loss: 0.0375 - val_accuracy: 0.9865 - val_loss: 0.0394 - learning_rate: 0.0110
# Epoch 58/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9914 - loss: 0.0280
# Epoch 58: val_accuracy improved from 0.98654 to 0.98910, saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
#
# Epoch 58: finished saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 75ms/step - accuracy: 0.9915 - loss: 0.0264 - val_accuracy: 0.9891 - val_loss: 0.0310 - learning_rate: 0.0107
# Epoch 59/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9926 - loss: 0.0254
# Epoch 59: val_accuracy did not improve from 0.98910
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.9934 - loss: 0.0219 - val_accuracy: 0.9868 - val_loss: 0.0330 - learning_rate: 0.0105
# Epoch 60/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9930 - loss: 0.0236
# Epoch 60: val_accuracy did not improve from 0.98910
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 64ms/step - accuracy: 0.9940 - loss: 0.0220 - val_accuracy: 0.9868 - val_loss: 0.0376 - learning_rate: 0.0103
# Epoch 61/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9925 - loss: 0.0224
# Epoch 61: val_accuracy did not improve from 0.98910
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 10s 62ms/step - accuracy: 0.9932 - loss: 0.0205 - val_accuracy: 0.9875 - val_loss: 0.0333 - learning_rate: 0.0100
# Epoch 62/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9947 - loss: 0.0181
# Epoch 62: val_accuracy did not improve from 0.98910
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.9952 - loss: 0.0169 - val_accuracy: 0.9889 - val_loss: 0.0296 - learning_rate: 0.0098
# Epoch 63/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9960 - loss: 0.0154
# Epoch 63: val_accuracy improved from 0.98910 to 0.98933, saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
#
# Epoch 63: finished saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.9965 - loss: 0.0135 - val_accuracy: 0.9893 - val_loss: 0.0303 - learning_rate: 0.0096
# Epoch 64/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9953 - loss: 0.0169
# Epoch 64: val_accuracy improved from 0.98933 to 0.98956, saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
#
# Epoch 64: finished saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.9950 - loss: 0.0167 - val_accuracy: 0.9896 - val_loss: 0.0345 - learning_rate: 0.0094
# Epoch 65/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9944 - loss: 0.0163
# Epoch 65: val_accuracy did not improve from 0.98956
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.9952 - loss: 0.0153 - val_accuracy: 0.9875 - val_loss: 0.0325 - learning_rate: 0.0092
# Epoch 66/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9964 - loss: 0.0129
# Epoch 66: val_accuracy improved from 0.98956 to 0.99234, saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
#
# Epoch 66: finished saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 12s 118ms/step - accuracy: 0.9964 - loss: 0.0128 - val_accuracy: 0.9923 - val_loss: 0.0238 - learning_rate: 0.0090
# Epoch 67/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9970 - loss: 0.0116
# Epoch 67: val_accuracy did not improve from 0.99234
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.9971 - loss: 0.0106 - val_accuracy: 0.9879 - val_loss: 0.0347 - learning_rate: 0.0088
# Epoch 68/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9893 - loss: 0.0334
# Epoch 68: val_accuracy did not improve from 0.99234
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.9943 - loss: 0.0189 - val_accuracy: 0.9810 - val_loss: 0.0671 - learning_rate: 0.0085
# Epoch 69/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9961 - loss: 0.0136
# Epoch 69: val_accuracy improved from 0.99234 to 0.99258, saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
#
# Epoch 69: finished saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 12s 79ms/step - accuracy: 0.9970 - loss: 0.0121 - val_accuracy: 0.9926 - val_loss: 0.0213 - learning_rate: 0.0083
# Epoch 70/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9963 - loss: 0.0121
# Epoch 70: val_accuracy did not improve from 0.99258
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.9967 - loss: 0.0113 - val_accuracy: 0.9905 - val_loss: 0.0266 - learning_rate: 0.0081
# Epoch 71/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9968 - loss: 0.0111
# Epoch 71: val_accuracy did not improve from 0.99258
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 70ms/step - accuracy: 0.9968 - loss: 0.0106 - val_accuracy: 0.9926 - val_loss: 0.0228 - learning_rate: 0.0080
# Epoch 72/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9975 - loss: 0.0099
# Epoch 72: val_accuracy did not improve from 0.99258
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.9975 - loss: 0.0094 - val_accuracy: 0.9921 - val_loss: 0.0231 - learning_rate: 0.0078
# Epoch 73/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9978 - loss: 0.0089
# Epoch 73: val_accuracy did not improve from 0.99258
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 64ms/step - accuracy: 0.9979 - loss: 0.0082 - val_accuracy: 0.9889 - val_loss: 0.0347 - learning_rate: 0.0076
# Epoch 74/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9968 - loss: 0.0088
# Epoch 74: val_accuracy improved from 0.99258 to 0.99374, saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
#
# Epoch 74: finished saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 75ms/step - accuracy: 0.9976 - loss: 0.0080 - val_accuracy: 0.9937 - val_loss: 0.0178 - learning_rate: 0.0074
# Epoch 75/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9978 - loss: 0.0082
# Epoch 75: val_accuracy did not improve from 0.99374
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 9s 64ms/step - accuracy: 0.9974 - loss: 0.0089 - val_accuracy: 0.9923 - val_loss: 0.0229 - learning_rate: 0.0072
# Epoch 76/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9976 - loss: 0.0095
# Epoch 76: val_accuracy did not improve from 0.99374
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.9977 - loss: 0.0088 - val_accuracy: 0.9896 - val_loss: 0.0341 - learning_rate: 0.0071
# Epoch 77/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9979 - loss: 0.0085
# Epoch 77: val_accuracy did not improve from 0.99374
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 64ms/step - accuracy: 0.9984 - loss: 0.0072 - val_accuracy: 0.9933 - val_loss: 0.0170 - learning_rate: 0.0069
# Epoch 78/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9984 - loss: 0.0057
# Epoch 78: val_accuracy did not improve from 0.99374
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.9981 - loss: 0.0069 - val_accuracy: 0.9921 - val_loss: 0.0258 - learning_rate: 0.0068
# Epoch 79/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9980 - loss: 0.0071
# Epoch 79: val_accuracy did not improve from 0.99374
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.9985 - loss: 0.0063 - val_accuracy: 0.9930 - val_loss: 0.0176 - learning_rate: 0.0066
# Epoch 80/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9991 - loss: 0.0049
# Epoch 80: val_accuracy did not improve from 0.99374
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.9985 - loss: 0.0057 - val_accuracy: 0.9928 - val_loss: 0.0222 - learning_rate: 0.0065
# Epoch 81/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9977 - loss: 0.0069
# Epoch 81: val_accuracy did not improve from 0.99374
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.9981 - loss: 0.0069 - val_accuracy: 0.9930 - val_loss: 0.0218 - learning_rate: 0.0063
# Epoch 82/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9973 - loss: 0.0080
# Epoch 82: val_accuracy improved from 0.99374 to 0.99490, saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
#
# Epoch 82: finished saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.9988 - loss: 0.0051 - val_accuracy: 0.9949 - val_loss: 0.0142 - learning_rate: 0.0062
# Epoch 83/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9983 - loss: 0.0059
# Epoch 83: val_accuracy did not improve from 0.99490
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.9985 - loss: 0.0058 - val_accuracy: 0.9933 - val_loss: 0.0159 - learning_rate: 0.0061
# Epoch 84/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9992 - loss: 0.0051
# Epoch 84: val_accuracy did not improve from 0.99490
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.9990 - loss: 0.0048 - val_accuracy: 0.9942 - val_loss: 0.0165 - learning_rate: 0.0059
# Epoch 85/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9989 - loss: 0.0050
# Epoch 85: val_accuracy did not improve from 0.99490
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.9989 - loss: 0.0048 - val_accuracy: 0.9923 - val_loss: 0.0199 - learning_rate: 0.0058
# Epoch 86/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9984 - loss: 0.0059
# Epoch 86: val_accuracy did not improve from 0.99490
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 65ms/step - accuracy: 0.9986 - loss: 0.0052 - val_accuracy: 0.9926 - val_loss: 0.0200 - learning_rate: 0.0057
# Epoch 87/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9987 - loss: 0.0049
# Epoch 87: val_accuracy did not improve from 0.99490
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 64ms/step - accuracy: 0.9991 - loss: 0.0046 - val_accuracy: 0.9940 - val_loss: 0.0161 - learning_rate: 0.0056
# Epoch 88/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9983 - loss: 0.0066
# Epoch 88: val_accuracy did not improve from 0.99490
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 64ms/step - accuracy: 0.9982 - loss: 0.0063 - val_accuracy: 0.9930 - val_loss: 0.0168 - learning_rate: 0.0055
# Epoch 89/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9994 - loss: 0.0041
# Epoch 89: val_accuracy did not improve from 0.99490
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.9995 - loss: 0.0043 - val_accuracy: 0.9940 - val_loss: 0.0135 - learning_rate: 0.0055
# Epoch 90/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9981 - loss: 0.0056
# Epoch 90: val_accuracy did not improve from 0.99490
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.9985 - loss: 0.0053 - val_accuracy: 0.9937 - val_loss: 0.0154 - learning_rate: 0.0054
# Epoch 91/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9992 - loss: 0.0043
# Epoch 91: val_accuracy did not improve from 0.99490
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.9994 - loss: 0.0037 - val_accuracy: 0.9949 - val_loss: 0.0134 - learning_rate: 0.0053
# Epoch 92/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9991 - loss: 0.0045
# Epoch 92: val_accuracy did not improve from 0.99490
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.9990 - loss: 0.0046 - val_accuracy: 0.9933 - val_loss: 0.0156 - learning_rate: 0.0052
# Epoch 93/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9989 - loss: 0.0044
# Epoch 93: val_accuracy improved from 0.99490 to 0.99513, saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
#
# Epoch 93: finished saving model to /content/drive/My Drive/Classification/baseline/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 10s 95ms/step - accuracy: 0.9989 - loss: 0.0042 - val_accuracy: 0.9951 - val_loss: 0.0139 - learning_rate: 0.0052
# Epoch 94/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9990 - loss: 0.0043
# Epoch 94: val_accuracy did not improve from 0.99513
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.9994 - loss: 0.0034 - val_accuracy: 0.9951 - val_loss: 0.0126 - learning_rate: 0.0051
# Epoch 95/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9998 - loss: 0.0033
# Epoch 95: val_accuracy did not improve from 0.99513
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 64ms/step - accuracy: 0.9998 - loss: 0.0032 - val_accuracy: 0.9937 - val_loss: 0.0147 - learning_rate: 0.0051
# Epoch 96/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9986 - loss: 0.0064
# Epoch 96: val_accuracy did not improve from 0.99513
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 65ms/step - accuracy: 0.9991 - loss: 0.0047 - val_accuracy: 0.9942 - val_loss: 0.0137 - learning_rate: 0.0051
# Epoch 97/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9988 - loss: 0.0044
# Epoch 97: val_accuracy did not improve from 0.99513
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.9987 - loss: 0.0043 - val_accuracy: 0.9935 - val_loss: 0.0161 - learning_rate: 0.0050
# Epoch 98/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9993 - loss: 0.0035
# Epoch 98: val_accuracy did not improve from 0.99513
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.9995 - loss: 0.0028 - val_accuracy: 0.9928 - val_loss: 0.0172 - learning_rate: 0.0050
# Epoch 99/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9995 - loss: 0.0037
# Epoch 99: val_accuracy did not improve from 0.99513
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.9995 - loss: 0.0033 - val_accuracy: 0.9937 - val_loss: 0.0158 - learning_rate: 0.0050
# Epoch 100/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9991 - loss: 0.0039
# Epoch 100: val_accuracy did not improve from 0.99513
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.9994 - loss: 0.0033 - val_accuracy: 0.9935 - val_loss: 0.0191 - learning_rate: 0.0050
# AlexNet_CNN completed full training: 100/100 epochs.
#
# ========================= Training GFNet (legacy_arch) =========================
# Epoch 1/100
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step - accuracy: 0.4690 - loss: 1.8169
# Epoch 1: val_loss improved from None to 0.92330, saving model to /content/drive/My Drive/Classification/baseline/models/GFNet_best.keras
#
# Epoch 1: finished saving model to /content/drive/My Drive/Classification/baseline/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 59s 355ms/step - accuracy: 0.5708 - loss: 1.3325 - val_accuracy: 0.7231 - val_loss: 0.9233
# Epoch 2/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.7384 - loss: 0.8542
# Epoch 2: val_loss improved from 0.92330 to 0.72210, saving model to /content/drive/My Drive/Classification/baseline/models/GFNet_best.keras
#
# Epoch 2: finished saving model to /content/drive/My Drive/Classification/baseline/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 97ms/step - accuracy: 0.7569 - loss: 0.8148 - val_accuracy: 0.8314 - val_loss: 0.7221
# Epoch 3/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.8228 - loss: 0.6765
# Epoch 3: val_loss improved from 0.72210 to 0.64499, saving model to /content/drive/My Drive/Classification/baseline/models/GFNet_best.keras
#
# Epoch 3: finished saving model to /content/drive/My Drive/Classification/baseline/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 96ms/step - accuracy: 0.8226 - loss: 0.6731 - val_accuracy: 0.8616 - val_loss: 0.6450
# Epoch 4/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.8584 - loss: 0.5987
# Epoch 4: val_loss improved from 0.64499 to 0.56297, saving model to /content/drive/My Drive/Classification/baseline/models/GFNet_best.keras
#
# Epoch 4: finished saving model to /content/drive/My Drive/Classification/baseline/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 98ms/step - accuracy: 0.8546 - loss: 0.6044 - val_accuracy: 0.8964 - val_loss: 0.5630
# Epoch 5/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.8876 - loss: 0.5384
# Epoch 5: val_loss improved from 0.56297 to 0.51537, saving model to /content/drive/My Drive/Classification/baseline/models/GFNet_best.keras
#
# Epoch 5: finished saving model to /content/drive/My Drive/Classification/baseline/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 95ms/step - accuracy: 0.8838 - loss: 0.5474 - val_accuracy: 0.9053 - val_loss: 0.5154
# Epoch 6/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.8961 - loss: 0.5120
# Epoch 6: val_loss improved from 0.51537 to 0.51115, saving model to /content/drive/My Drive/Classification/baseline/models/GFNet_best.keras
#
# Epoch 6: finished saving model to /content/drive/My Drive/Classification/baseline/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 95ms/step - accuracy: 0.8971 - loss: 0.5125 - val_accuracy: 0.9064 - val_loss: 0.5111
# Epoch 7/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9092 - loss: 0.4879
# Epoch 7: val_loss improved from 0.51115 to 0.50119, saving model to /content/drive/My Drive/Classification/baseline/models/GFNet_best.keras
#
# Epoch 7: finished saving model to /content/drive/My Drive/Classification/baseline/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 93ms/step - accuracy: 0.9111 - loss: 0.4853 - val_accuracy: 0.9080 - val_loss: 0.5012
# Epoch 8/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9171 - loss: 0.4567
# Epoch 8: val_loss improved from 0.50119 to 0.45397, saving model to /content/drive/My Drive/Classification/baseline/models/GFNet_best.keras
#
# Epoch 8: finished saving model to /content/drive/My Drive/Classification/baseline/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 98ms/step - accuracy: 0.9185 - loss: 0.4543 - val_accuracy: 0.9296 - val_loss: 0.4540
# Epoch 9/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.9322 - loss: 0.4305
# Epoch 9: val_loss did not improve from 0.45397
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 85ms/step - accuracy: 0.9315 - loss: 0.4331 - val_accuracy: 0.9374 - val_loss: 0.4554
# Epoch 10/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9323 - loss: 0.4241
# Epoch 10: val_loss improved from 0.45397 to 0.44961, saving model to /content/drive/My Drive/Classification/baseline/models/GFNet_best.keras
#
# Epoch 10: finished saving model to /content/drive/My Drive/Classification/baseline/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 93ms/step - accuracy: 0.9325 - loss: 0.4242 - val_accuracy: 0.9408 - val_loss: 0.4496
# Epoch 11/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9388 - loss: 0.4133
# Epoch 11: val_loss improved from 0.44961 to 0.44063, saving model to /content/drive/My Drive/Classification/baseline/models/GFNet_best.keras
#
# Epoch 11: finished saving model to /content/drive/My Drive/Classification/baseline/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 95ms/step - accuracy: 0.9397 - loss: 0.4089 - val_accuracy: 0.9358 - val_loss: 0.4406
# Epoch 12/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9505 - loss: 0.3857
# Epoch 12: val_loss improved from 0.44063 to 0.38260, saving model to /content/drive/My Drive/Classification/baseline/models/GFNet_best.keras
#
# Epoch 12: finished saving model to /content/drive/My Drive/Classification/baseline/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 93ms/step - accuracy: 0.9512 - loss: 0.3828 - val_accuracy: 0.9621 - val_loss: 0.3826
# Epoch 13/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9582 - loss: 0.3735
# Epoch 13: val_loss improved from 0.38260 to 0.36648, saving model to /content/drive/My Drive/Classification/baseline/models/GFNet_best.keras
#
# Epoch 13: finished saving model to /content/drive/My Drive/Classification/baseline/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 96ms/step - accuracy: 0.9525 - loss: 0.3825 - val_accuracy: 0.9648 - val_loss: 0.3665
# Epoch 14/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9667 - loss: 0.3540
# Epoch 14: val_loss did not improve from 0.36648
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 85ms/step - accuracy: 0.9623 - loss: 0.3619 - val_accuracy: 0.9664 - val_loss: 0.3753
# Epoch 15/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9656 - loss: 0.3494
# Epoch 15: val_loss improved from 0.36648 to 0.36563, saving model to /content/drive/My Drive/Classification/baseline/models/GFNet_best.keras
#
# Epoch 15: finished saving model to /content/drive/My Drive/Classification/baseline/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 97ms/step - accuracy: 0.9646 - loss: 0.3534 - val_accuracy: 0.9702 - val_loss: 0.3656
# Epoch 16/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9707 - loss: 0.3424
# Epoch 16: val_loss improved from 0.36563 to 0.35581, saving model to /content/drive/My Drive/Classification/baseline/models/GFNet_best.keras
#
# Epoch 16: finished saving model to /content/drive/My Drive/Classification/baseline/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 93ms/step - accuracy: 0.9698 - loss: 0.3439 - val_accuracy: 0.9776 - val_loss: 0.3558
# Epoch 17/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9721 - loss: 0.3322
# Epoch 17: val_loss did not improve from 0.35581
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 86ms/step - accuracy: 0.9710 - loss: 0.3341 - val_accuracy: 0.9737 - val_loss: 0.3573
# Epoch 18/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9735 - loss: 0.3317
# Epoch 18: val_loss improved from 0.35581 to 0.34716, saving model to /content/drive/My Drive/Classification/baseline/models/GFNet_best.keras
#
# Epoch 18: finished saving model to /content/drive/My Drive/Classification/baseline/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 93ms/step - accuracy: 0.9728 - loss: 0.3345 - val_accuracy: 0.9814 - val_loss: 0.3472
# Epoch 19/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9795 - loss: 0.3176
# Epoch 19: val_loss did not improve from 0.34716
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 86ms/step - accuracy: 0.9785 - loss: 0.3191 - val_accuracy: 0.9733 - val_loss: 0.3729
# Epoch 20/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9726 - loss: 0.3275
# Epoch 20: val_loss did not improve from 0.34716
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 84ms/step - accuracy: 0.9746 - loss: 0.3271 - val_accuracy: 0.9799 - val_loss: 0.3536
# Epoch 21/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9781 - loss: 0.3218
# Epoch 21: val_loss improved from 0.34716 to 0.32581, saving model to /content/drive/My Drive/Classification/baseline/models/GFNet_best.keras
#
# Epoch 21: finished saving model to /content/drive/My Drive/Classification/baseline/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 94ms/step - accuracy: 0.9823 - loss: 0.3120 - val_accuracy: 0.9888 - val_loss: 0.3258
# Epoch 22/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9855 - loss: 0.3046
# Epoch 22: val_loss did not improve from 0.32581
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 84ms/step - accuracy: 0.9834 - loss: 0.3098 - val_accuracy: 0.9845 - val_loss: 0.3380
# Epoch 23/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9815 - loss: 0.3106
# Epoch 23: val_loss improved from 0.32581 to 0.31583, saving model to /content/drive/My Drive/Classification/baseline/models/GFNet_best.keras
#
# Epoch 23: finished saving model to /content/drive/My Drive/Classification/baseline/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 94ms/step - accuracy: 0.9837 - loss: 0.3084 - val_accuracy: 0.9923 - val_loss: 0.3158
# Epoch 24/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9893 - loss: 0.2960
# Epoch 24: val_loss improved from 0.31583 to 0.31444, saving model to /content/drive/My Drive/Classification/baseline/models/GFNet_best.keras
#
# Epoch 24: finished saving model to /content/drive/My Drive/Classification/baseline/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 93ms/step - accuracy: 0.9885 - loss: 0.2977 - val_accuracy: 0.9930 - val_loss: 0.3144
# Epoch 25/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9913 - loss: 0.2929
# Epoch 25: val_loss did not improve from 0.31444
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 86ms/step - accuracy: 0.9887 - loss: 0.2965 - val_accuracy: 0.9869 - val_loss: 0.3310
# Epoch 26/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9878 - loss: 0.2987
# Epoch 26: val_loss did not improve from 0.31444
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 84ms/step - accuracy: 0.9874 - loss: 0.2998 - val_accuracy: 0.9896 - val_loss: 0.3195
# Epoch 27/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9933 - loss: 0.2873
# Epoch 27: val_loss did not improve from 0.31444
# ...
# Epoch 49/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9899 - loss: 0.2927
# Epoch 49: val_loss did not improve from 0.28554
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 149ms/step - accuracy: 0.9908 - loss: 0.2920 - val_accuracy: 0.9845 - val_loss: 0.2997
# Epoch 50/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9932 - loss: 0.2849
# Epoch 50: val_loss did not improve from 0.28554
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 148ms/step - accuracy: 0.9931 - loss: 0.2864 - val_accuracy: 0.9869 - val_loss: 0.2922
# Epoch 51/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9967 - loss: 0.2766
# Epoch 51: val_loss did not improve from 0.28554
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 149ms/step - accuracy: 0.9956 - loss: 0.2795 - val_accuracy: 0.9853 - val_loss: 0.2992
# Epoch 52/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9940 - loss: 0.2824
# Epoch 52: val_loss did not improve from 0.28554
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 149ms/step - accuracy: 0.9923 - loss: 0.2862 - val_accuracy: 0.9865 - val_loss: 0.2964
# Epoch 53/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9950 - loss: 0.2793
# Epoch 53: val_loss did not improve from 0.28554
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 149ms/step - accuracy: 0.9956 - loss: 0.2790 - val_accuracy: 0.9896 - val_loss: 0.2864
# Epoch 54/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9932 - loss: 0.2829
# Epoch 54: val_loss did not improve from 0.28554
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 149ms/step - accuracy: 0.9943 - loss: 0.2805 - val_accuracy: 0.9899 - val_loss: 0.2861
# Epoch 55/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9961 - loss: 0.2786
# Epoch 55: val_loss improved from 0.28554 to 0.28274, saving model to /content/drive/My Drive/Classification/baseline/models/ViT_UNet_best.keras
#
# Epoch 55: finished saving model to /content/drive/My Drive/Classification/baseline/models/ViT_UNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 14s 172ms/step - accuracy: 0.9968 - loss: 0.2776 - val_accuracy: 0.9915 - val_loss: 0.2827
# Epoch 56/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9969 - loss: 0.2749
# Epoch 56: val_loss did not improve from 0.28274
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 153ms/step - accuracy: 0.9967 - loss: 0.2756 - val_accuracy: 0.9861 - val_loss: 0.2985
# Epoch 57/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9967 - loss: 0.2762
# Epoch 57: val_loss did not improve from 0.28274
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 159ms/step - accuracy: 0.9971 - loss: 0.2750 - val_accuracy: 0.9892 - val_loss: 0.2848
# Epoch 58/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9967 - loss: 0.2756
# Epoch 58: val_loss did not improve from 0.28274
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 149ms/step - accuracy: 0.9964 - loss: 0.2781 - val_accuracy: 0.9869 - val_loss: 0.2920
# Epoch 59/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9953 - loss: 0.2799
# Epoch 59: val_loss did not improve from 0.28274
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 149ms/step - accuracy: 0.9956 - loss: 0.2785 - val_accuracy: 0.9903 - val_loss: 0.2892
# Epoch 60/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9964 - loss: 0.2755
# Epoch 60: val_loss did not improve from 0.28274
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 149ms/step - accuracy: 0.9969 - loss: 0.2748 - val_accuracy: 0.9888 - val_loss: 0.2888
# Epoch 61/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9955 - loss: 0.2770
# Epoch 61: val_loss improved from 0.28274 to 0.28025, saving model to /content/drive/My Drive/Classification/baseline/models/ViT_UNet_best.keras
#
# Epoch 61: finished saving model to /content/drive/My Drive/Classification/baseline/models/ViT_UNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 14s 167ms/step - accuracy: 0.9960 - loss: 0.2761 - val_accuracy: 0.9919 - val_loss: 0.2803
# Epoch 62/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9971 - loss: 0.2740
# Epoch 62: val_loss improved from 0.28025 to 0.27775, saving model to /content/drive/My Drive/Classification/baseline/models/ViT_UNet_best.keras
#
# Epoch 62: finished saving model to /content/drive/My Drive/Classification/baseline/models/ViT_UNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 18s 227ms/step - accuracy: 0.9973 - loss: 0.2734 - val_accuracy: 0.9923 - val_loss: 0.2777
# Epoch 63/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9988 - loss: 0.2693
# Epoch 63: val_loss did not improve from 0.27775
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 149ms/step - accuracy: 0.9989 - loss: 0.2694 - val_accuracy: 0.9919 - val_loss: 0.2794
# Epoch 64/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.9983 - loss: 0.2699
# Epoch 64: val_loss improved from 0.27775 to 0.27510, saving model to /content/drive/My Drive/Classification/baseline/models/ViT_UNet_best.keras
#
# Epoch 64: finished saving model to /content/drive/My Drive/Classification/baseline/models/ViT_UNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 19s 237ms/step - accuracy: 0.9975 - loss: 0.2719 - val_accuracy: 0.9923 - val_loss: 0.2751
# Epoch 65/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9972 - loss: 0.2716
# Epoch 65: val_loss did not improve from 0.27510
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 153ms/step - accuracy: 0.9979 - loss: 0.2712 - val_accuracy: 0.9927 - val_loss: 0.2756
# Epoch 66/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.9984 - loss: 0.2703
# Epoch 66: val_loss improved from 0.27510 to 0.27508, saving model to /content/drive/My Drive/Classification/baseline/models/ViT_UNet_best.keras
#
# Epoch 66: finished saving model to /content/drive/My Drive/Classification/baseline/models/ViT_UNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 245ms/step - accuracy: 0.9980 - loss: 0.2705 - val_accuracy: 0.9946 - val_loss: 0.2751
# Epoch 67/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9988 - loss: 0.2704
# Epoch 67: val_loss improved from 0.27508 to 0.27109, saving model to /content/drive/My Drive/Classification/baseline/models/ViT_UNet_best.keras
#
# Epoch 67: finished saving model to /content/drive/My Drive/Classification/baseline/models/ViT_UNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 16s 201ms/step - accuracy: 0.9986 - loss: 0.2702 - val_accuracy: 0.9934 - val_loss: 0.2711
# Epoch 68/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9984 - loss: 0.2719
# Epoch 68: val_loss did not improve from 0.27109
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 153ms/step - accuracy: 0.9985 - loss: 0.2710 - val_accuracy: 0.9930 - val_loss: 0.2734
# Epoch 69/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9990 - loss: 0.2683
# Epoch 69: val_loss did not improve from 0.27109
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 149ms/step - accuracy: 0.9988 - loss: 0.2691 - val_accuracy: 0.9942 - val_loss: 0.2721
# Epoch 70/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9999 - loss: 0.2662
# Epoch 70: val_loss did not improve from 0.27109
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 152ms/step - accuracy: 0.9997 - loss: 0.2670 - val_accuracy: 0.9950 - val_loss: 0.2712
# Epoch 71/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9996 - loss: 0.2664
# Epoch 71: val_loss did not improve from 0.27109
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 152ms/step - accuracy: 0.9996 - loss: 0.2667 - val_accuracy: 0.9938 - val_loss: 0.2745
# Epoch 72/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9998 - loss: 0.2665
# Epoch 72: val_loss did not improve from 0.27109
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 148ms/step - accuracy: 0.9997 - loss: 0.2670 - val_accuracy: 0.9938 - val_loss: 0.2721
# Epoch 73/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9993 - loss: 0.2671
# Epoch 73: val_loss did not improve from 0.27109
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 147ms/step - accuracy: 0.9989 - loss: 0.2684 - val_accuracy: 0.9923 - val_loss: 0.2804
# Epoch 74/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9992 - loss: 0.2673
# Epoch 74: val_loss did not improve from 0.27109
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 148ms/step - accuracy: 0.9987 - loss: 0.2682 - val_accuracy: 0.9861 - val_loss: 0.2985
# Epoch 75/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9993 - loss: 0.2676
# Epoch 75: val_loss did not improve from 0.27109
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 148ms/step - accuracy: 0.9993 - loss: 0.2673 - val_accuracy: 0.9923 - val_loss: 0.2764
# Epoch 76/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9993 - loss: 0.2665
# Epoch 76: val_loss did not improve from 0.27109
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 152ms/step - accuracy: 0.9991 - loss: 0.2674 - val_accuracy: 0.9927 - val_loss: 0.2783
# Epoch 77/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9995 - loss: 0.2664
# Epoch 77: val_loss improved from 0.27109 to 0.27002, saving model to /content/drive/My Drive/Classification/baseline/models/ViT_UNet_best.keras
#
# Epoch 77: finished saving model to /content/drive/My Drive/Classification/baseline/models/ViT_UNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 14s 168ms/step - accuracy: 0.9997 - loss: 0.2662 - val_accuracy: 0.9950 - val_loss: 0.2700
# Epoch 78/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9999 - loss: 0.2654
# Epoch 78: val_loss did not improve from 0.27002
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 152ms/step - accuracy: 0.9996 - loss: 0.2661 - val_accuracy: 0.9942 - val_loss: 0.2748
# Epoch 79/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9998 - loss: 0.2660
# Epoch 79: val_loss did not improve from 0.27002
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 156ms/step - accuracy: 0.9996 - loss: 0.2666 - val_accuracy: 0.9950 - val_loss: 0.2729
# Epoch 80/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9994 - loss: 0.2665
# Epoch 80: val_loss did not improve from 0.27002
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 148ms/step - accuracy: 0.9993 - loss: 0.2669 - val_accuracy: 0.9946 - val_loss: 0.2703
# Epoch 81/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9996 - loss: 0.2660
# Epoch 81: val_loss did not improve from 0.27002
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 148ms/step - accuracy: 0.9994 - loss: 0.2665 - val_accuracy: 0.9930 - val_loss: 0.2764
# Epoch 82/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9997 - loss: 0.2672
# Epoch 82: val_loss did not improve from 0.27002
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 148ms/step - accuracy: 0.9998 - loss: 0.2661 - val_accuracy: 0.9934 - val_loss: 0.2715
# Epoch 83/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9999 - loss: 0.2660
# Epoch 83: val_loss did not improve from 0.27002
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 149ms/step - accuracy: 0.9997 - loss: 0.2663 - val_accuracy: 0.9938 - val_loss: 0.2765
# Epoch 84/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9996 - loss: 0.2659
# Epoch 84: val_loss did not improve from 0.27002
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 149ms/step - accuracy: 0.9994 - loss: 0.2664 - val_accuracy: 0.9930 - val_loss: 0.2763
# Epoch 85/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9996 - loss: 0.2656
# Epoch 85: val_loss did not improve from 0.27002
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 152ms/step - accuracy: 0.9996 - loss: 0.2658 - val_accuracy: 0.9942 - val_loss: 0.2728
# Epoch 86/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9992 - loss: 0.2663
# Epoch 86: val_loss did not improve from 0.27002
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 147ms/step - accuracy: 0.9995 - loss: 0.2661 - val_accuracy: 0.9942 - val_loss: 0.2743
# Epoch 87/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 1.0000 - loss: 0.2652
# Epoch 87: val_loss did not improve from 0.27002
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 147ms/step - accuracy: 0.9999 - loss: 0.2656 - val_accuracy: 0.9934 - val_loss: 0.2785
# Epoch 88/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9998 - loss: 0.2651
# Epoch 88: val_loss did not improve from 0.27002
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 149ms/step - accuracy: 0.9998 - loss: 0.2652 - val_accuracy: 0.9946 - val_loss: 0.2728
# Epoch 89/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9999 - loss: 0.2653
# Epoch 89: val_loss did not improve from 0.27002
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 149ms/step - accuracy: 0.9998 - loss: 0.2654 - val_accuracy: 0.9950 - val_loss: 0.2740
# Epoch 90/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 1.0000 - loss: 0.2649
# Epoch 90: val_loss did not improve from 0.27002
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 150ms/step - accuracy: 0.9999 - loss: 0.2650 - val_accuracy: 0.9927 - val_loss: 0.2754
# Epoch 91/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 1.0000 - loss: 0.2648
# Epoch 91: val_loss did not improve from 0.27002
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 152ms/step - accuracy: 0.9998 - loss: 0.2652 - val_accuracy: 0.9930 - val_loss: 0.2779
# Epoch 92/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9995 - loss: 0.2664
# Epoch 92: val_loss did not improve from 0.27002
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 149ms/step - accuracy: 0.9995 - loss: 0.2662 - val_accuracy: 0.9942 - val_loss: 0.2738
# Epoch 93/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 1.0000 - loss: 0.2649
# Epoch 93: val_loss did not improve from 0.27002
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 148ms/step - accuracy: 0.9999 - loss: 0.2648 - val_accuracy: 0.9942 - val_loss: 0.2736
# Epoch 94/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9995 - loss: 0.2656
# Epoch 94: val_loss did not improve from 0.27002
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 149ms/step - accuracy: 0.9996 - loss: 0.2654 - val_accuracy: 0.9934 - val_loss: 0.2757
# Epoch 95/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9997 - loss: 0.2650
# Epoch 95: val_loss did not improve from 0.27002
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 148ms/step - accuracy: 0.9997 - loss: 0.2652 - val_accuracy: 0.9934 - val_loss: 0.2774
# Epoch 96/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 1.0000 - loss: 0.2647
# Epoch 96: val_loss did not improve from 0.27002
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 149ms/step - accuracy: 0.9999 - loss: 0.2647 - val_accuracy: 0.9938 - val_loss: 0.2741
# Epoch 97/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 1.0000 - loss: 0.2646
# Epoch 97: val_loss did not improve from 0.27002
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 149ms/step - accuracy: 1.0000 - loss: 0.2648 - val_accuracy: 0.9942 - val_loss: 0.2747
# Epoch 98/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9996 - loss: 0.2649
# Epoch 98: val_loss did not improve from 0.27002
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 152ms/step - accuracy: 0.9998 - loss: 0.2650 - val_accuracy: 0.9938 - val_loss: 0.2736
# Epoch 99/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 1.0000 - loss: 0.2646
# Epoch 99: val_loss did not improve from 0.27002
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 149ms/step - accuracy: 1.0000 - loss: 0.2647 - val_accuracy: 0.9942 - val_loss: 0.2742
# Epoch 100/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 1.0000 - loss: 0.2648
# Epoch 100: val_loss did not improve from 0.27002
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 149ms/step - accuracy: 1.0000 - loss: 0.2647 - val_accuracy: 0.9942 - val_loss: 0.2717
# ViT_UNet completed full training: 100/100 epochs.
#          model capacity_tag  test_accuracy     kappa  macro_f1  weighted_f1  \
# 0        GFNet  legacy_arch       0.997448  0.996539  0.997135     0.997446
# 1     ViT_UNet  legacy_arch       0.994896  0.993080  0.993458     0.994899
# 2  AlexNet_CNN  legacy_arch       0.993503  0.991191  0.990701     0.993513
#
#     val_nll  test_nll  val_brier  test_brier  test_ece_15bin  \
# 0  0.013796  0.018461   0.002288    0.004583        0.009697
# 1  0.059104  0.060887   0.010825    0.011172        0.037185
# 2  0.019076  0.019076   0.009710    0.009710        0.002858
#
#    epochs_configured  epochs_ran  train_time_sec  \
# 0                100         100      786.719000
# 1                100         100     1474.442275
# 2                100         100      747.492000
#
#                                      best_model_path  \
# 0  /content/drive/My Drive/Classification/baselin...
# 1  /content/drive/My Drive/Classification/baselin...
# 2  /content/drive/My Drive/Classification/baselin...
#
#                                     final_model_path
# 0  /content/drive/My Drive/Classification/baselin...
# 1  /content/drive/My Drive/Classification/baselin...
# 2  /content/drive/My Drive/Classification/baselin...

# %% [markdown]
# # 7.0 — Results & Metrics
# Save classification summaries to CSV / JSON, then plot training curves, cross-model bar charts, calibration proxies, and confusion matrices.

# %% [markdown]
# ## 7.1 — Save summary CSV and per-model JSON reports

# %%
summary_path = RESULTS_DIR / "classification_summary.csv"
summary_df.to_csv(summary_path, index=False)
print("Saved summary:", summary_path)

for model_name, artifact in model_artifacts.items():
    report_path = RESULTS_DIR / f"{model_name}_classification_report.json"
    with open(report_path, "w", encoding="utf-8") as f:
        json.dump(artifact["report"], f, indent=2)

print("Per-model classification reports saved to:", RESULTS_DIR)
summary_df
# Out:
# Saved summary: /content/drive/My Drive/Classification/baseline/results/classification_summary.csv
# Per-model classification reports saved to: /content/drive/My Drive/Classification/baseline/results
#          model capacity_tag  test_accuracy     kappa  macro_f1  weighted_f1  \
# 0        GFNet  legacy_arch       0.997448  0.996539  0.997135     0.997446
# 1     ViT_UNet  legacy_arch       0.994896  0.993080  0.993458     0.994899
# 2  AlexNet_CNN  legacy_arch       0.993503  0.991191  0.990701     0.993513
#
#     val_nll  test_nll  val_brier  test_brier  test_ece_15bin  \
# 0  0.013796  0.018461   0.002288    0.004583        0.009697
# 1  0.059104  0.060887   0.010825    0.011172        0.037185
# 2  0.019076  0.019076   0.009710    0.009710        0.002858
#
#    epochs_configured  epochs_ran  train_time_sec  \
# 0                100         100      786.719000
# 1                100         100     1474.442275
# 2                100         100      747.492000
#
#                                      best_model_path  \
# 0  /content/drive/My Drive/Classification/baselin...
# 1  /content/drive/My Drive/Classification/baselin...
# 2  /content/drive/My Drive/Classification/baselin...
#
#                                     final_model_path
# 0  /content/drive/My Drive/Classification/baselin...
# 1  /content/drive/My Drive/Classification/baselin...
# 2  /content/drive/My Drive/Classification/baselin...

# %% [markdown]
# ## 7.2 — Training curves (accuracy and loss per epoch)

# %%
for model_name, artifact in model_artifacts.items():
    hist   = artifact["history"]
    epochs = np.arange(1, len(hist["loss"]) + 1)

    fig, ax1 = plt.subplots(figsize=(12, 5))
    ax1.plot(epochs, hist["accuracy"],     color="#1f77b4", linewidth=2,   label="Train Accuracy")
    ax1.plot(epochs, hist["val_accuracy"], color="#2ca02c", linewidth=2, linestyle="--", label="Val Accuracy")
    ax1.set_xlabel("Epoch")
    ax1.set_ylabel("Accuracy")
    ax1.set_ylim(0, 1.0)
    ax1.grid(True, alpha=0.25)

    ax2 = ax1.twinx()
    ax2.plot(epochs, hist["loss"],     color="#111111", linewidth=1.8,   label="Train Loss")
    ax2.plot(epochs, hist["val_loss"], color="#d62728", linewidth=1.8, linestyle="--", label="Val Loss")
    ax2.set_ylabel("Loss")

    lines  = ax1.get_lines() + ax2.get_lines()
    labels = [ln.get_label() for ln in lines]
    ax1.legend(lines, labels, loc="upper right", frameon=True)
    plt.title(f"{model_name}: Accuracy / Loss vs Epoch")
    plt.tight_layout()

    curve_path = PLOT_DIR / f"{model_name}_training_curves.png"
    plt.savefig(curve_path, dpi=200, bbox_inches="tight")
    plt.show()

# %% [markdown]
# ## 7.3 — Cross-model comparison bar charts

# %%
plot_df = summary_df[[
    "model", "test_accuracy", "macro_f1", "kappa", "train_time_sec",
    "test_nll", "test_brier", "test_ece_15bin",
]].copy()

fig, axes = plt.subplots(2, 2, figsize=(15, 9))
axes    = axes.flatten()
palette = ["#4c72b0", "#55a868", "#c44e52"]

metric_specs = [
    ("test_accuracy",  "Test Accuracy",   (0.0, 1.0), "{:.3f}"),
    ("macro_f1",       "Macro F1",        (0.0, 1.0), "{:.3f}"),
    ("kappa",          "Cohen Kappa",     (0.0, 1.0), "{:.3f}"),
    ("train_time_sec", "Train Time (sec)", None,       "{:.1f}"),
]

for ax, (col, title, ylim, fmt) in zip(axes, metric_specs):
    local = plot_df[["model", col]].copy()
    bars  = ax.bar(local["model"], local[col], color=palette[:len(local)])
    ax.set_title(title)
    ax.set_xlabel("Model")
    ax.set_ylabel(title)
    if ylim is not None:
        ax.set_ylim(*ylim)
    ax.grid(axis="y", alpha=0.25)
    for patch in bars:
        height = patch.get_height()
        xpos   = patch.get_x() + patch.get_width() / 2
        offset = (ylim[1] - ylim[0]) * 0.02 if ylim else max(local[col].max() * 0.02, 0.05)
        ax.text(xpos, height + offset, fmt.format(height), ha="center", va="bottom", fontsize=9)

plt.suptitle("Single-Head Model Comparison", y=1.02, fontsize=14)
plt.tight_layout()
comparison_path = PLOT_DIR / "model_comparison_metrics.png"
plt.savefig(comparison_path, dpi=200, bbox_inches="tight")
plt.show()

# %% [markdown]
# ## 7.4 — Calibration proxy metrics and confusion matrices

# %%
# Calibration proxy chart (lower is better for all three metrics)
fig, ax     = plt.subplots(figsize=(12, 5))
calib_cols  = ["test_nll", "test_brier", "test_ece_15bin"]
calib_df    = plot_df[["model"] + calib_cols].set_index("model")
calib_df.plot(kind="bar", ax=ax, rot=0)
ax.set_title("Uncertainty Proxy Metrics (Lower is Better)")
ax.set_ylabel("Metric Value")
ax.grid(axis="y", alpha=0.25)
plt.tight_layout()
calib_path = PLOT_DIR / "uncertainty_proxy_metrics.png"
plt.savefig(calib_path, dpi=200, bbox_inches="tight")
plt.show()

# Side-by-side confusion matrices
class_ticks = [str(i + 1) for i in range(num_classes)]
fig, axes   = plt.subplots(1, len(model_artifacts), figsize=(7 * len(model_artifacts), 5.5))
if len(model_artifacts) == 1:
    axes = [axes]

for ax, (model_name, artifact) in zip(axes, model_artifacts.items()):
    sns.heatmap(
        artifact["confusion_matrix"],
        annot=True, fmt="d", cmap="Blues",
        xticklabels=class_ticks, yticklabels=class_ticks,
        cbar=False, ax=ax,
    )
    ax.set_title(f"{model_name} Confusion Matrix")
    ax.set_xlabel("Predicted")
    ax.set_ylabel("True")

plt.tight_layout()
cm_path = PLOT_DIR / "confusion_matrices_side_by_side.png"
plt.savefig(cm_path, dpi=220, bbox_inches="tight")
plt.show()
print("Saved confusion matrix figure:", cm_path)
print("All training plots saved to:", PLOT_DIR)
# Out:
# Saved confusion matrix figure: /content/drive/My Drive/Classification/baseline/results/training_plots/confusion_matrices_side_by_side.png
# All training plots saved to: /content/drive/My Drive/Classification/baseline/results/training_plots

# %% [markdown]
# # 8.0 — Scene Visualisation
# Load the saved best models, run dense patch-by-patch inference over the entire scene, and save classified maps as PNGs and an Excel workbook.

# %% [markdown]
# ## 8.1 — Visualisation helpers

# %%
CUSTOM_OBJECTS = {
    "PatchExtractor":      PatchExtractor,
    "PatchPositionEncoder": PatchPositionEncoder,
    "GlobalFilterLayer":   GlobalFilterLayer,
    "PatchEncoderWithCLS": PatchEncoderWithCLS,
}


def get_scene_rgb(x_img, bands):
    """Select three bands as an approximate RGB composite; clip to [0, 1]."""
    if bands >= 6:
        rgb_idx = [bands // 2 - 1, bands // 2, bands // 2 + 1]
    elif bands >= 3:
        rgb_idx = [0, 1, 2]
    else:
        raise ValueError(f"Need at least 3 bands to form RGB, got {bands}.")
    return np.clip(x_img[:, :, rgb_idx], 0.0, 1.0)


def get_display_cmap(num_classes):
    """Build a ListedColormap: index 0 = background black, 1..K = class colours."""
    return ListedColormap([BACKGROUND_COLOR] + get_class_colors(num_classes))


def predict_full_scene_labels(model, x_img, patch_size=9, batch_size=256):
    """Run dense sliding-window inference row-by-row; returns a (H, W) label map."""
    pad   = patch_size // 2
    x_pad = np.pad(x_img, ((pad, pad), (pad, pad), (0, 0)), mode="edge")
    preds = np.zeros((x_img.shape[0], x_img.shape[1]), dtype=np.int32)

    for r in range(x_img.shape[0]):
        row_patches = np.empty(
            (x_img.shape[1], patch_size, patch_size, x_img.shape[-1]),
            dtype=np.float32,
        )
        for c in range(x_img.shape[1]):
            row_patches[c] = x_pad[r:r + patch_size, c:c + patch_size, :]

        row_prob  = model.predict(row_patches, batch_size=batch_size, verbose=0)
        preds[r]  = np.argmax(row_prob, axis=1) + 1  # back to 1..K

    return preds


def load_saved_models_for_visualization(model_dir, custom_objects):
    """Attempt to load all three best models; return dicts of loaded and missing."""
    model_files = {
        "AlexNet_CNN": model_dir / "AlexNet_CNN_best.keras",
        "GFNet":       model_dir / "GFNet_best.keras",
        "ViT_UNet":    model_dir / "ViT_UNet_best.keras",
    }
    loaded, missing = {}, {}
    for model_key, model_path in model_files.items():
        if not model_path.exists():
            missing[model_key] = f"Missing file: {model_path}"
            continue
        try:
            loaded[model_key] = keras.models.load_model(
                model_path, custom_objects=custom_objects,
                compile=False, safe_mode=False,
            )
        except Exception as exc:
            missing[model_key] = f"Load failed: {exc}"
    return loaded, missing


def save_single_panel(image, title, save_path, cmap=None, vmin=None, vmax=None):
    """Save a single image panel as a high-DPI PNG."""
    fig, ax = plt.subplots(figsize=(8, 6))
    if cmap is None:
        ax.imshow(image)
    else:
        ax.imshow(image, cmap=cmap, vmin=vmin, vmax=vmax)
    ax.set_title(title, fontsize=14)
    ax.axis("off")
    fig.tight_layout()
    fig.savefig(save_path, dpi=220, bbox_inches="tight")
    plt.show()
    plt.close(fig)
    print("Saved:", save_path)


def save_combined_overview(rgb_image, y_true, pred_maps, missing_info, num_classes, save_path):
    """Save a five-panel side-by-side overview: RGB, GT, and one panel per model."""
    cmap   = get_display_cmap(num_classes)
    panels = [
        ("Approximate RGB",             rgb_image,               "rgb"),
        ("True Label Map",              y_true,                  "label"),
        ("AlexNet Initial Classification", pred_maps.get("AlexNet_CNN"), "label"),
        ("GFNet Initial Classification",   pred_maps.get("GFNet"),       "label"),
        ("ViT Initial Classification",     pred_maps.get("ViT_UNet"),    "label"),
    ]

    fig, axes = plt.subplots(1, len(panels), figsize=(30, 7), sharex=True, sharey=True)
    for ax, (title, img, kind) in zip(axes, panels):
        ax.set_title(title, fontsize=13)
        if kind == "rgb":
            ax.imshow(img)
        elif img is None:
            ax.imshow(np.zeros_like(y_true), cmap=cmap, vmin=0, vmax=num_classes)
            key = {"AlexNet": "AlexNet_CNN", "GFNet": "GFNet", "ViT": "ViT_UNet"}.get(
                next((k for k in ("AlexNet", "GFNet", "ViT") if k in title), None)
            )
            ax.text(0.5, 0.5, missing_info.get(key, "Unavailable"),
                    ha="center", va="center", fontsize=10, wrap=True, transform=ax.transAxes)
        else:
            ax.imshow(img, cmap=cmap, vmin=0, vmax=num_classes)
        ax.axis("off")

    handles = [plt.Rectangle((0, 0), 1, 1, color=BACKGROUND_COLOR, label="Background")]
    class_colors = get_class_colors(num_classes)
    for i in range(num_classes):
        handles.append(plt.Rectangle((0, 0), 1, 1, color=class_colors[i], label=f"Class {i+1}"))
    fig.legend(handles=handles, loc="lower center", ncol=min(num_classes + 1, 8),
               bbox_to_anchor=(0.5, -0.02), frameon=True)
    fig.tight_layout(rect=[0, 0.05, 1, 1])
    fig.savefig(save_path, dpi=220, bbox_inches="tight")
    plt.show()
    plt.close(fig)
    print("Saved:", save_path)


def save_images_to_excel(excel_path, image_paths, sheet_name="Initial_Classification_Maps"):
    """Embed PNG images into an Excel workbook at fixed anchor positions."""
    if excel_path.exists():
        wb = load_workbook(excel_path)
        if sheet_name in wb.sheetnames:
            del wb[sheet_name]
        ws = wb.create_sheet(title=sheet_name)
    else:
        wb = Workbook()
        ws = wb.active
        ws.title = sheet_name

    anchors = ["A1", "J1", "A25", "J25", "A49", "J49"]
    for path, anchor in zip(image_paths, anchors):
        if path.exists():
            img        = XLImage(str(path))
            img.anchor = anchor
            ws.add_image(img)

    wb.save(excel_path)
    print("Saved Excel workbook:", excel_path)

# %% [markdown]
# ## 8.2 — Generate and save all scene maps

# %%
scene_rgb    = get_scene_rgb(x_img, B)
display_cmap = get_display_cmap(num_classes)

loaded_models, missing_models = load_saved_models_for_visualization(MODEL_DIR, CUSTOM_OBJECTS)
prediction_maps = {}

for model_key, loaded_model in loaded_models.items():
    print(f"Generating full-scene classified image for {model_key}...")
    prediction_maps[model_key] = predict_full_scene_labels(
        loaded_model, x_img, patch_size=PATCH_SIZE, batch_size=BATCH_SIZE,
    )
    print(f"{model_key} map shape:", prediction_maps[model_key].shape)

if missing_models:
    print("Some models could not be loaded:")
    for model_key, reason in missing_models.items():
        print(f"  - {model_key}: {reason}")

# Individual PNG paths
rgb_png      = VIS_DIR / "scene_rgb.png"
gt_png       = VIS_DIR / "ground_truth_label_map.png"
alex_png     = VIS_DIR / "AlexNet_CNN_initial_classification.png"
gfnet_png    = VIS_DIR / "GFNet_initial_classification.png"
vit_png      = VIS_DIR / "ViT_UNet_initial_classification.png"
overview_png = VIS_DIR / "combined_initial_classification_overview.png"

save_single_panel(scene_rgb, "Approximate RGB", rgb_png)
save_single_panel(y_img, "Ground Truth Label Map", gt_png, cmap=display_cmap, vmin=0, vmax=num_classes)

if prediction_maps.get("AlexNet_CNN") is not None:
    save_single_panel(prediction_maps["AlexNet_CNN"], "AlexNet Initial Classification",
                      alex_png, cmap=display_cmap, vmin=0, vmax=num_classes)

if prediction_maps.get("GFNet") is not None:
    save_single_panel(prediction_maps["GFNet"], "GFNet Initial Classification",
                      gfnet_png, cmap=display_cmap, vmin=0, vmax=num_classes)

if prediction_maps.get("ViT_UNet") is not None:
    save_single_panel(prediction_maps["ViT_UNet"], "ViT Initial Classification",
                      vit_png, cmap=display_cmap, vmin=0, vmax=num_classes)

save_combined_overview(
    rgb_image=scene_rgb, y_true=y_img, pred_maps=prediction_maps,
    missing_info=missing_models, num_classes=num_classes, save_path=overview_png,
)

image_paths_for_excel = [rgb_png, gt_png, alex_png, gfnet_png, vit_png, overview_png]
save_images_to_excel(VIS_EXCEL_PATH, image_paths_for_excel, sheet_name="Initial_Classification_Maps")

print("All visualisation outputs saved to:", VIS_DIR)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
